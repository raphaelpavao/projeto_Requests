# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"43881352233","type":"IssuesEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":877846153,"name":"kaiyunsports-cn/kaiyunguanwang","url":"https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang"},"payload":{"action":"opened","issue":{"url":"https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130","repository_url":"https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang","labels_url":"https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/labels{/name}","comments_url":"https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/comments","events_url":"https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/events","html_url":"https://github.com/kaiyunsports-cn/kaiyunguanwang/issues/110130","id":2663488588,"node_id":"I_kwDONFLeic6ewZxM","number":110130,"title":"👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平","user":{"login":"github-actions[bot]","id":41898282,"node_id":"MDM6Qm90NDE4OTgyODI=","avatar_url":"https://avatars.githubusercontent.com/in/15368?v=4","gravatar_id":"","url":"https://api.github.com/users/github-actions%5Bbot%5D","html_url":"https://github.com/apps/github-actions","followers_url":"https://api.github.com/users/github-actions%5Bbot%5D/followers","following_url":"https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}","gists_url":"https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}","starred_url":"https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/github-actions%5Bbot%5D/subscriptions","organizations_url":"https://api.github.com/users/github-actions%5Bbot%5D/orgs","repos_url":"https://api.github.com/users/github-actions%5Bbot%5D/repos","events_url":"https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}","received_events_url":"https://api.github.com/users/github-actions%5Bbot%5D/received_events","type":"Bot","user_view_type":"public","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":0,"created_at":"2024-11-15T23:40:56Z","updated_at":"2024-11-15T23:40:56Z","closed_at":null,"author_association":"NONE","active_lock_reason":null,"body":"# 👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平\\n\\n  ## 👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平\\n\\n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平是一家专注于体育赛事的在线娱乐提供商提供体育赛事直播投注、真人娱乐、棋牌、电竞等，网站注重用户体验，提供便捷的注册和登录，支持多平台和多设备的访问👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平邀您每日观五大联赛领豪礼，每日每场皆有奖，请点击下面注册入口进行查看~\\n\\n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平网页版：👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平网页版为用户提供全方位的服务，友好的界面和流畅的操作体验，支持多平台访问，随时随地都能享受到最新最热门的体育和娱乐游戏。对于部分海外地区的用户，可能需要使用VPN才能访问👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平网站。\\n  \\n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平体育App：提供业内最高赔率，覆盖世界各地的赛事，可供用户进行多元竞猜，如让球、大小、半全场、波胆等多种玩法。此外，平台还提供动画直播功能，让用户轻松地观看比赛，同时也可以进行娱乐投注，两者兼顾，尽享乐趣。\\n  \\n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平全站App：全站App是一款专门为体育爱好者和游戏玩家设计的应用程序，具备流畅的操作和良好的用户体验。用户可以在应用中畅玩海量的体育、电竞顶尖赛事、真人娱乐、彩票投注和电子游艺等娱乐项目。\\n  \\n  【Tag:】🤣CBA名场面：杜锋进攻回合口哨声吓到黄荣奇造成失误 被梅森断球打成反击, 🤕名记：锡安-威廉森因生病缺席与公牛的比赛 遭遇车祸的阿尔瓦拉多大概率出战, 😓有点离谱了！勇士揭幕战开局4分钟8中0 其中三分5中0仅靠罚球得到3分, 🐮美媒晒独行侠2022年与2024年揭幕战首发对比：全面升级, 🌟火箭战黄蜂首发：格林PK三球, 🐮美媒晒独行侠2022年与2024年揭幕战首发对比：全面升级, 🤕黄蜂后卫布兰登-米勒臀部受伤 本场比赛不会回归, 🔥状态奇佳！申京出场8分钟即砍下9分11板接近两双的数据, 🔥76人战雄鹿首发出炉：恩比德乔治缺阵 马克西出战, 😨老鹰球员丹尼尔斯上篮被克拉克斯顿恶意犯规 后者直接驱逐\\n\\n  ### 相关推荐：\\n\\n  <https://ky-kaiyun-sports.com>\\n  <https://ky-kaiyun-tiyu.com>\\n  <https://kaiyun-sports-games.com>\\n  <https://kaiyun-sports-zh.com>\\n  <https://kaiyun-sports-cn.com>\\n  <https://cn-kaiyun-sports.com>\\n  <https://zh-kaiyun-sports.com>\\n  <https://game-kaiyun-sports.com>\\n  <https://game-kaiyun-tiyu.com>\\n  <https://online-kaiyun-tiyu.com>\\n  <https://qiusu-speed.com>\\n  <https://qiusu-zh.com>\\n  <https://qiusu-web.com>\\n  <https://qiusutiyu-game.com>\\n  ...

# %%
r.json()
# Out:
# [{'id': '43881352233',
#   'type': 'IssuesEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 877846153,
#    'name': 'kaiyunsports-cn/kaiyunguanwang',
#    'url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130',
#     'repository_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang',
#     'labels_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/comments',
#     'events_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/events',
#     'html_url': 'https://github.com/kaiyunsports-cn/kaiyunguanwang/issues/110130',
#     'id': 2663488588,
#     'node_id': 'I_kwDONFLeic6ewZxM',
#     'number': 110130,
#     'title': '👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2024-11-15T23:40:56Z',
#     'updated_at': '2024-11-15T23:40:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '# 👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平\n\n  ## 👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平\n\n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平是一家专注于体育赛事的在线娱乐提供商提供体育赛事直播投注、真人娱乐、棋牌、电竞等，网站注重用户体验，提供便捷的注册和登录，支持多平台和多设备的访问👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平邀您每日观五大联赛领豪礼，每日每场皆有奖，请点击下面注册入口进行查看~\n\n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平网页版：👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平网页版为用户提供全方位的服务，友好的界面和流畅的操作体验，支持多平台访问，随时随地都能享受到最新最热门的体育和娱乐游戏。对于部分海外地区的用户，可能需要使用VPN才能访问👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平网站。\n  \n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平体育App：提供业内最高赔率，覆盖世界各地的赛事，可供用户进行多元竞猜，如让球、大小、半全场、波胆等多种玩法。此外，平台还提供动画直播功能，让用户轻松地观看比赛，同时也可以进行娱乐投注，两者兼顾，尽享乐趣。\n  \n  👀老鹰开局2分钟轰13分 此后4分钟一分不得 篮网趁机将分差抹平全站App：全站App是一款专门为体育爱好者和游戏玩家设计的应用程序，具备流畅的操作和良好的用户体验。用户可以在应用中畅玩海量的体育、电竞顶尖赛事、真人娱乐、彩票投注和电子游艺等娱乐项目。\n  \n  【Tag:】🤣CBA名场面：杜锋进攻回合口哨声吓到黄荣奇造成失误 被梅森断球打成反击, 🤕名记：锡安-威廉森因生病缺席与公牛的比赛 遭遇车祸的阿尔瓦拉多大概率出战, 😓有点离谱了！勇士揭幕战开局4分钟8中0 其中三分5中0仅靠罚球得到3分, 🐮美媒晒独行侠2022年与2024年揭幕战首发对比：全面升级, 🌟火箭战黄蜂首发：格林PK三球, 🐮美媒晒独行侠2022年与2024年揭幕战首发对比：全面升级, 🤕黄蜂后卫布兰登-米勒臀部受伤 本场比赛不会回归, 🔥状态奇佳！申京出场8分钟即砍下9分11板接近两双的数据, 🔥76人战雄鹿首发出炉：恩比德乔治缺阵 马克西出战, 😨老鹰球员丹尼尔斯上篮被克拉克斯顿恶意犯规 后者直接驱逐\n\n  ### 相关推荐：\n\n  <https://ky-kaiyun-sports.com>\n  <https://ky-kaiyun-tiyu.com>\n  <https://kaiyun-sports-games.com>\n  <https://kaiyun-sports-zh.com>\n  <https://kaiyun-sports-cn.com>\n  <https://cn-kaiyun-sports.com>\n  <https://zh-kaiyun-sports.com>\n  <https://game-kaiyun-sports.com>\n  <https://game-kaiyun-tiyu.com>\n  <https://online-kaiyun-tiyu.com>\n  <https://qiusu-speed.com>\n  <https://qiusu-zh.com>\n  <https://qiusu-web.com>\n  <https://qiusutiyu-game.com>\n  <https://qiusutiyu-online.com>\n  <https://qiususports-online.com>\n  <https://qiususports-game.com>\n  <https://sports-qiusutiyu.com>\n  <https://game-ballspeed.com>\n  <https://online-ballspeed.com>\n  <https://leyutiyu-zh.com>\n  <https://leyusports-zh.com>\n  <https://cn-leyutiyu.com>\n  <https://net-leyutiyu.com>\n  <https://leyuty-sports.com>\n  <https://leyutiyu-wb.com>\n  <https://leyusports-wb.com>\n  <https://leyusports-ch.com>\n  <https://sports-leyusports.com>\n  <https://games-leyusports.com>\n  <https://www.ky-kaiyun-sports.com>\n  <https://www.ky-kaiyun-tiyu.com>\n  <https://www.kaiyun-sports-games.com>\n  <https://www.kaiyun-sports-zh.com>\n  <https://www.kaiyun-sports-cn.com>\n  <https://www.cn-kaiyun-sports.com>\n  <https://www.zh-kaiyun-sports.com>\n  <https://www.game-kaiyun-sports.com>\n  <https://www.game-kaiyun-tiyu.com>\n  <https://www.online-kaiyun-tiyu.com>\n  <https://www.qiusu-speed.com>\n  <https://www.qiusu-zh.com>\n  <https://www.qiusu-web.com>\n  <https://www.qiusutiyu-game.com>\n  <https://www.qiusutiyu-online.com>\n  <https://www.qiususports-online.com>\n  <https://www.qiususports-game.com>\n  <https://www.sports-qiusutiyu.com>\n  <https://www.game-ballspeed.com>\n  <https://www.online-ballspeed.com>\n  <https://www.leyutiyu-zh.com>\n  <https://www.leyusports-zh.com>\n  <https://www.cn-leyutiyu.com>\n  <https://www.net-leyutiyu.com>\n  <https://www.leyuty-sports.com>\n  <https://www.leyutiyu-wb.com>\n  <https://www.leyusports-wb.com>\n  <https://www.leyusports-ch.com>\n  <https://www.sports-leyusports.com>\n  <https://www.games-leyusports.com>\n  <https://m.ky-kaiyun-sports.com>\n  <https://m.ky-kaiyun-tiyu.com>\n  <https://m.kaiyun-sports-games.com>\n  <https://m.kaiyun-sports-zh.com>\n  <https://m.kaiyun-sports-cn.com>\n  <https://m.cn-kaiyun-sports.com>\n  <https://m.zh-kaiyun-sports.com>\n  <https://m.game-kaiyun-sports.com>\n  <https://m.game-kaiyun-tiyu.com>\n  <https://m.online-kaiyun-tiyu.com>\n  <https://m.qiusu-speed.com>\n  <https://m.qiusu-zh.com>\n  <https://m.qiusu-web.com>\n  <https://m.qiusutiyu-game.com>\n  <https://m.qiusutiyu-online.com>\n  <https://m.qiususports-online.com>\n  <https://m.qiususports-game.com>\n  <https://m.sports-qiusutiyu.com>\n  <https://m.game-ballspeed.com>\n  <https://m.online-ballspeed.com>\n  <https://m.leyutiyu-zh.com>\n  <https://m.leyusports-zh.com>\n  <https://m.cn-leyutiyu.com>\n  <https://m.net-leyutiyu.com>\n  <https://m.leyuty-sports. ...
#     'reactions': {'url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunguanwang/issues/110130/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z'},
#  {'id': '43881352232',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 119911947,
#    'login': 'Wang20030509',
#    'display_login': 'Wang20030509',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Wang20030509',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119911947?'},
#   'repo': {'id': 876269554,
#    'name': 'Kaguya-kyuu/Translator-program',
#    'url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program'},
#   'payload': {'action': 'opened',
#    'number': 14,
#    'pull_request': {'url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/14',
#     'id': 2182784883,
#     'node_id': 'PR_kwDONDrP8s6CGqdz',
#     'html_url': 'https://github.com/Kaguya-kyuu/Translator-program/pull/14',
#     'diff_url': 'https://github.com/Kaguya-kyuu/Translator-program/pull/14.diff',
#     'patch_url': 'https://github.com/Kaguya-kyuu/Translator-program/pull/14.patch',
#     'issue_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/14',
#     'number': 14,
#     'state': 'open',
#     'locked': False,
#     'title': 'Update the InMemoryUserDataAccessObject',
#     'user': {'login': 'Wang20030509',
#      'id': 119911947,
#      'node_id': 'U_kgDOByW2Cw',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/119911947?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Wang20030509',
#      'html_url': 'https://github.com/Wang20030509',
#      'followers_url': 'https://api.github.com/users/Wang20030509/followers',
#      'following_url': 'https://api.github.com/users/Wang20030509/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Wang20030509/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Wang20030509/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Wang20030509/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Wang20030509/orgs',
#      'repos_url': 'https://api.github.com/users/Wang20030509/repos',
#      'events_url': 'https://api.github.com/users/Wang20030509/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Wang20030509/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2024-11-15T23:40:55Z',
#     'updated_at': '2024-11-15T23:40:55Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/14/commits',
#     'review_comments_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/14/comments',
#     'review_comment_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/14/comments',
#     'statuses_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/statuses/4bd6fffda6c7598442a991be03105abdc9f25561',
#     'head': {'label': 'Kaguya-kyuu:doran',
#      'ref': 'doran',
#      'sha': '4bd6fffda6c7598442a991be03105abdc9f25561',
#      'user': {'login': 'Kaguya-kyuu',
#       'id': 180045379,
#       'node_id': 'U_kgDOCrtGQw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/180045379?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Kaguya-kyuu',
#       'html_url': 'https://github.com/Kaguya-kyuu',
#       'followers_url': 'https://api.github.com/users/Kaguya-kyuu/followers',
#       'following_url': 'https://api.github.com/users/Kaguya-kyuu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Kaguya-kyuu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Kaguya-kyuu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Kaguya-kyuu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Kaguya-kyuu/orgs',
#       'repos_url': 'https://api.github.com/users/Kaguya-kyuu/repos',
#       'events_url': 'https://api.github.com/users/Kaguya-kyuu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Kaguya-kyuu/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 876269554,
#       'node_id': 'R_kgDONDrP8g',
#       'name': 'Translator-program',
#       'full_name': 'Kaguya-kyuu/Translator-program',
#       'private': False,
#       'owner': {'login': 'Kaguya-kyuu',
#        'id': 180045379,
#        'node_id': 'U_kgDOCrtGQw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/180045379?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Kaguya-kyuu',
#        'html_url': 'https://github.com/Kaguya-kyuu',
#        'followers_url': 'https://api.github.com/users/Kaguya-kyuu/followers',
#        'following_url': 'https://api.github.com/users/Kaguya-kyuu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Kaguya-kyuu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Kaguya-kyuu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Kaguya-kyuu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Kaguya-kyuu/orgs',
#        'repos_url': 'https://api.github.com/users/Kaguya-kyuu/repos',
#        'events_url': 'https://api.github.com/users/Kaguya-kyuu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Kaguya-kyuu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Kaguya-kyuu/Translator-program',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program',
#       'forks_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/forks',
#       'keys_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/teams',
#       'hooks_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/events',
#       'assignees_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/tags',
#       'blobs_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/languages',
#       'stargazers_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/subscription',
#       'commits_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/merges',
#       'archive_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/downloads',
#       'issues_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/deployments',
#       'created_at': '2024-10-21T17:23:35Z',
#       'updated_at': '2024-11-15T23:30:22Z',
#       'pushed_at': '2024-11-15T23:40:44Z',
#       'git_url': 'git://github.com/Kaguya-kyuu/Translator-program.git',
#       'ssh_url': 'git@github.com:Kaguya-kyuu/Translator-program.git',
#       'clone_url': 'https://github.com/Kaguya-kyuu/Translator-program.git',
#       'svn_url': 'https://github.com/Kaguya-kyuu/Translator-program',
#       'homepage': None,
#       'size': 371,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'cc0-1.0',
#        'name': 'Creative Commons Zero v1.0 Universal',
#        'spdx_id': 'CC0-1.0',
#        'url': 'https://api.github.com/licenses/cc0-1.0',
#        'node_id': 'MDc6TGljZW5zZTY='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'Kaguya-kyuu:main',
#      'ref': 'main',
#      'sha': '1bfcb7193ad87bb270c83559bbeea0e565c25954',
#      'user': {'login': 'Kaguya-kyuu',
#       'id': 180045379,
#       'node_id': 'U_kgDOCrtGQw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/180045379?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Kaguya-kyuu',
#       'html_url': 'https://github.com/Kaguya-kyuu',
#       'followers_url': 'https://api.github.com/users/Kaguya-kyuu/followers',
#       'following_url': 'https://api.github.com/users/Kaguya-kyuu/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Kaguya-kyuu/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Kaguya-kyuu/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Kaguya-kyuu/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Kaguya-kyuu/orgs',
#       'repos_url': 'https://api.github.com/users/Kaguya-kyuu/repos',
#       'events_url': 'https://api.github.com/users/Kaguya-kyuu/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Kaguya-kyuu/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 876269554,
#       'node_id': 'R_kgDONDrP8g',
#       'name': 'Translator-program',
#       'full_name': 'Kaguya-kyuu/Translator-program',
#       'private': False,
#       'owner': {'login': 'Kaguya-kyuu',
#        'id': 180045379,
#        'node_id': 'U_kgDOCrtGQw',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/180045379?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Kaguya-kyuu',
#        'html_url': 'https://github.com/Kaguya-kyuu',
#        'followers_url': 'https://api.github.com/users/Kaguya-kyuu/followers',
#        'following_url': 'https://api.github.com/users/Kaguya-kyuu/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Kaguya-kyuu/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Kaguya-kyuu/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Kaguya-kyuu/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Kaguya-kyuu/orgs',
#        'repos_url': 'https://api.github.com/users/Kaguya-kyuu/repos',
#        'events_url': 'https://api.github.com/users/Kaguya-kyuu/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Kaguya-kyuu/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/Kaguya-kyuu/Translator-program',
#       'description': None,
#       'fork': True,
#       'url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program',
#       'forks_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/forks',
#       'keys_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/teams',
#       'hooks_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/events',
#       'assignees_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/tags',
#       'blobs_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/languages',
#       'stargazers_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/subscription',
#       'commits_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/merges',
#       'archive_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/downloads',
#       'issues_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/deployments',
#       'created_at': '2024-10-21T17:23:35Z',
#       'updated_at': '2024-11-15T23:30:22Z',
#       'pushed_at': '2024-11-15T23:40:44Z',
#       'git_url': 'git://github.com/Kaguya-kyuu/Translator-program.git',
#       'ssh_url': 'git@github.com:Kaguya-kyuu/Translator-program.git',
#       'clone_url': 'https://github.com/Kaguya-kyuu/Translator-program.git',
#       'svn_url': 'https://github.com/Kaguya-kyuu/Translator-program',
#       'homepage': None,
#       'size': 371,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': False,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'cc0-1.0',
#        'name': 'Creative Commons Zero v1.0 Universal',
#        'spdx_id': 'CC0-1.0',
#        'url': 'https://api.github.com/licenses/cc0-1.0',
#        'node_id': 'MDc6TGljZW5zZTY='},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/14'},
#      'html': {'href': 'https://github.com/Kaguya-kyuu/Translator-program/pull/14'},
#      'issue': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/14'},
#      'comments': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/issues/14/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/14/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/pulls/14/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Kaguya-kyuu/Translator-program/statuses/4bd6fffda6c7598442a991be03105abdc9f25561'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 61,
#     'deletions': 15,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z'},
#  {'id': '43881352231',
#   'type': 'IssuesEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 877845466,
#    'name': 'kaiyunsports-cn/kaiyunyule',
#    'url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule/issues/105941',
#     'repository_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule',
#     'labels_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule/issues/105941/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule/issues/105941/comments',
#     'events_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule/issues/105941/events',
#     'html_url': 'https://github.com/kaiyunsports-cn/kaiyunyule/issues/105941',
#     'id': 2663488593,
#     'node_id': 'I_kwDONFLb2s6ewZxR',
#     'number': 105941,
#     'title': '无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2024-11-15T23:40:56Z',
#     'updated_at': '2024-11-15T23:40:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '# 无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛\n\n  ## 无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛\n\n  无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛是一家专注于体育赛事的在线娱乐提供商提供体育赛事直播投注、真人娱乐、棋牌、电竞等，网站注重用户体验，提供便捷的注册和登录，支持多平台和多设备的访问无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛邀您每日观五大联赛领豪礼，每日每场皆有奖，请点击下面注册入口进行查看~\n\n  无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛网页版：无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛网页版为用户提供全方位的服务，友好的界面和流畅的操作体验，支持多平台访问，随时随地都能享受到最新最热门的体育和娱乐游戏。对于部分海外地区的用户，可能需要使用VPN才能访问无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛网站。\n  \n  无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛体育App：提供业内最高赔率，覆盖世界各地的赛事，可供用户进行多元竞猜，如让球、大小、半全场、波胆等多种玩法。此外，平台还提供动画直播功能，让用户轻松地观看比赛，同时也可以进行娱乐投注，两者兼顾，尽享乐趣。\n  \n  无奈空砍！格林轰28分 申京25+18+5+致命失误葬送比赛全站App：全站App是一款专门为体育爱好者和游戏玩家设计的应用程序，具备流畅的操作和良好的用户体验。用户可以在应用中畅玩海量的体育、电竞顶尖赛事、真人娱乐、彩票投注和电子游艺等娱乐项目。\n  \n  【Tag:】🤕黄蜂后卫布兰登-米勒臀部受伤 本场比赛不会回归, 😂NBA也甘拜下风！澳篮两队首节10分钟命中8记三分球狂轰60分, 🏀上海VS宁波前瞻：沃特斯状态火热冲连胜 拉科塞维奇能否率队逆袭？, 🤕Shams：鹈鹕球员德章泰-穆雷可能遭遇左手骨折, 🤨唱对台戏？TMZ曝詹姆斯父子同台前遭车祸起诉并要求二人赔偿, 😂战术鬼才？科尔在第二节初换上穆迪 勇士已有12人轮换出场, 🤕此前宣布不再出战背靠背比赛！Shams：NBA可能会对恩比德展开调查, 🤕黄蜂后卫布兰登-米勒臀部受伤 本场比赛不会回归, 💢快船全队上半场仅得39分 而同时开打的勇士次节就得到41分, 🧐大牌回归倒计时！媒体人：赵睿顺利通过CBA体测\n\n  ### 相关推荐：\n\n  <https://ky-kaiyun-sports.com>\n  <https://ky-kaiyun-tiyu.com>\n  <https://kaiyun-sports-games.com>\n  <https://kaiyun-sports-zh.com>\n  <https://kaiyun-sports-cn.com>\n  <https://cn-kaiyun-sports.com>\n  <https://zh-kaiyun-sports.com>\n  <https://game-kaiyun-sports.com>\n  <https://game-kaiyun-tiyu.com>\n  <https://online-kaiyun-tiyu.com>\n  <https://qiusu-speed.com>\n  <https://qiusu-zh.com>\n  <https://qiusu-web.com>\n  <https://qiusutiyu-game.com>\n  <https://qiusutiyu-online.com>\n  <https://qiususports-online.com>\n  <https://qiususports-game.com>\n  <https://sports-qiusutiyu.com>\n  <https://game-ballspeed.com>\n  <https://online-ballspeed.com>\n  <https://leyutiyu-zh.com>\n  <https://leyusports-zh.com>\n  <https://cn-leyutiyu.com>\n  <https://net-leyutiyu.com>\n  <https://leyuty-sports.com>\n  <https://leyutiyu-wb.com>\n  <https://leyusports-wb.com>\n  <https://leyusports-ch.com>\n  <https://sports-leyusports.com>\n  <https://games-leyusports.com>\n  <https://www.ky-kaiyun-sports.com>\n  <https://www.ky-kaiyun-tiyu.com>\n  <https://www.kaiyun-sports-games.com>\n  <https://www.kaiyun-sports-zh.com>\n  <https://www.kaiyun-sports-cn.com>\n  <https://www.cn-kaiyun-sports.com>\n  <https://www.zh-kaiyun-sports.com>\n  <https://www.game-kaiyun-sports.com>\n  <https://www.game-kaiyun-tiyu.com>\n  <https://www.online-kaiyun-tiyu.com>\n  <https://www.qiusu-speed.com>\n  <https://www.qiusu-zh.com>\n  <https://www.qiusu-web.com>\n  <https://www.qiusutiyu-game.com>\n  <https://www.qiusutiyu-online.com>\n  <https://www.qiususports-online.com>\n  <https://www.qiususports-game.com>\n  <https://www.sports-qiusutiyu.com>\n  <https://www.game-ballspeed.com>\n  <https://www.online-ballspeed.com>\n  <https://www.leyutiyu-zh.com>\n  <https://www.leyusports-zh.com>\n  <https://www.cn-leyutiyu.com>\n  <https://www.net-leyutiyu.com>\n  <https://www.leyuty-sports.com>\n  <https://www.leyutiyu-wb.com>\n  <https://www.leyusports-wb.com>\n  <https://www.leyusports-ch.com>\n  <https://www.sports-leyusports.com>\n  <https://www.games-leyusports.com>\n  <https://m.ky-kaiyun-sports.com>\n  <https://m.ky-kaiyun-tiyu.com>\n  <https://m.kaiyun-sports-games.com>\n  <https://m.kaiyun-sports-zh.com>\n  <https://m.kaiyun-sports-cn.com>\n  <https://m.cn-kaiyun-sports.com>\n  <https://m.zh-kaiyun-sports.com>\n  <https://m.game-kaiyun-sports.com>\n  <https://m.game-kaiyun-tiyu.com>\n  <https://m.online-kaiyun-tiyu.com>\n  <https://m.qiusu-speed.com>\n  <https://m.qiusu-zh.com>\n  <https://m.qiusu-web.com>\n  <https://m.qiusutiyu-game.com>\n  <https://m.qiusutiyu-online.com>\n  <https://m.qiususports-online.com>\n  <https://m.qiususports-game.com>\n  <https://m.sports-qiusutiyu.com>\n  <https://m.game-ballspeed.com>\n  <https://m.online-ballspeed.com>\n  <https://m.leyutiyu-zh.com>\n  <https://m.leyusports-zh.com>\n  <https://m.cn-leyutiyu.com>\n  <https://m.net-leyutiyu.com>\n  <https://m.leyuty-sports.com>\n  <https://m.le ...
#     'reactions': {'url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule/issues/105941/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kaiyunsports-cn/kaiyunyule/issues/105941/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z'},
#  {'id': '43881352230',
#   'type': 'IssuesEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 878373987,
#    'name': 'kysports-cn/kytiyusports-cn.github.io',
#    'url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io/issues/121812',
#     'repository_url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io',
#     'labels_url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io/issues/121812/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io/issues/121812/comments',
#     'events_url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io/issues/121812/events',
#     'html_url': 'https://github.com/kysports-cn/kytiyusports-cn.github.io/issues/121812',
#     'id': 2663488585,
#     'node_id': 'I_kwDONFrsY86ewZxJ',
#     'number': 121812,
#     'title': '状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红',
#     'user': {'login': 'github-actions[bot]',
#      'id': 41898282,
#      'node_id': 'MDM6Qm90NDE4OTgyODI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/15368?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/github-actions%5Bbot%5D',
#      'html_url': 'https://github.com/apps/github-actions',
#      'followers_url': 'https://api.github.com/users/github-actions%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/github-actions%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/github-actions%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/github-actions%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/github-actions%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/github-actions%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/github-actions%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/github-actions%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2024-11-15T23:40:56Z',
#     'updated_at': '2024-11-15T23:40:56Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': '# 状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红\n\n  ## 状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红\n\n  状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红是一家专注于体育赛事的在线娱乐提供商提供体育赛事直播投注、真人娱乐、棋牌、电竞等，网站注重用户体验，提供便捷的注册和登录，支持多平台和多设备的访问状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红邀您每日观五大联赛领豪礼，每日每场皆有奖，请点击下面注册入口进行查看~\n\n  状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红网页版：状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红网页版为用户提供全方位的服务，友好的界面和流畅的操作体验，支持多平台访问，随时随地都能享受到最新最热门的体育和娱乐游戏。对于部分海外地区的用户，可能需要使用VPN才能访问状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红网站。\n  \n  状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红体育App：提供业内最高赔率，覆盖世界各地的赛事，可供用户进行多元竞猜，如让球、大小、半全场、波胆等多种玩法。此外，平台还提供动画直播功能，让用户轻松地观看比赛，同时也可以进行娱乐投注，两者兼顾，尽享乐趣。\n  \n  状态火爆！塔图姆三节轰下37分10助 凯尔特人迎开门红全站App：全站App是一款专门为体育爱好者和游戏玩家设计的应用程序，具备流畅的操作和良好的用户体验。用户可以在应用中畅玩海量的体育、电竞顶尖赛事、真人娱乐、彩票投注和电子游艺等娱乐项目。\n  \n  【Tag:】🏀NBA半场：塔图姆25+6&布伦森15分 两队合计命中21记三分球 绿军74-55尼克斯, 🏀女篮亚冠战报：韩旭12分 四川统治全场以83-45击败泗水狂热, 👀Shams：爱德华兹与NFL球星贾斯汀-杰弗逊致敬加内特与莫斯的照片版本发布, 😞詹姆斯超越科比成为NBA历史打铁王, 🔥精彩！生力啤最后2.4秒投进大心脏四分球 基尼巴国王造犯规两罚全中 两队进入加时, 😂NBA也甘拜下风！澳篮两队首节10分钟命中8记三分球狂轰60分, 📸雷速海报：上阵父子兵！詹姆斯&布朗尼成为NBA首对同台作战的父子组合, 🌟欧洲篮球联赛球员薪水排名：维琴科夫370万欧元居首 多位前NBA球员上榜, 🙈可怕！凯尔特人下半场开局两分钟三分球三连中 分差扩大到26分, 😎追上来了！布里斯班子弹次节后半段吹响反击号角 半场落后凤凰4分\n\n  ### 相关推荐：\n\n  <https://ky-kytiyu-sports.com>\n  <https://ky-kytiyu-tiyu.com>\n  <https://kytiyu-sports-games.com>\n  <https://kytiyu-sports-zh.com>\n  <https://kytiyu-sports-cn.com>\n  <https://cn-kytiyu-sports.com>\n  <https://zh-kytiyu-sports.com>\n  <https://game-kytiyu-sports.com>\n  <https://game-kytiyu-tiyu.com>\n  <https://online-kytiyu-tiyu.com>\n  <https://qiusu-speed.com>\n  <https://qiusu-zh.com>\n  <https://qiusu-web.com>\n  <https://qiusutiyu-game.com>\n  <https://qiusutiyu-online.com>\n  <https://qiususports-online.com>\n  <https://qiususports-game.com>\n  <https://sports-qiusutiyu.com>\n  <https://game-ballspeed.com>\n  <https://online-ballspeed.com>\n  <https://leyutiyu-zh.com>\n  <https://leyusports-zh.com>\n  <https://cn-leyutiyu.com>\n  <https://net-leyutiyu.com>\n  <https://leyuty-sports.com>\n  <https://leyutiyu-wb.com>\n  <https://leyusports-wb.com>\n  <https://leyusports-ch.com>\n  <https://sports-leyusports.com>\n  <https://games-leyusports.com>\n  <https://www.ky-kytiyu-sports.com>\n  <https://www.ky-kytiyu-tiyu.com>\n  <https://www.kytiyu-sports-games.com>\n  <https://www.kytiyu-sports-zh.com>\n  <https://www.kytiyu-sports-cn.com>\n  <https://www.cn-kytiyu-sports.com>\n  <https://www.zh-kytiyu-sports.com>\n  <https://www.game-kytiyu-sports.com>\n  <https://www.game-kytiyu-tiyu.com>\n  <https://www.online-kytiyu-tiyu.com>\n  <https://www.qiusu-speed.com>\n  <https://www.qiusu-zh.com>\n  <https://www.qiusu-web.com>\n  <https://www.qiusutiyu-game.com>\n  <https://www.qiusutiyu-online.com>\n  <https://www.qiususports-online.com>\n  <https://www.qiususports-game.com>\n  <https://www.sports-qiusutiyu.com>\n  <https://www.game-ballspeed.com>\n  <https://www.online-ballspeed.com>\n  <https://www.leyutiyu-zh.com>\n  <https://www.leyusports-zh.com>\n  <https://www.cn-leyutiyu.com>\n  <https://www.net-leyutiyu.com>\n  <https://www.leyuty-sports.com>\n  <https://www.leyutiyu-wb.com>\n  <https://www.leyusports-wb.com>\n  <https://www.leyusports-ch.com>\n  <https://www.sports-leyusports.com>\n  <https://www.games-leyusports.com>\n  <https://m.ky-kytiyu-sports.com>\n  <https://m.ky-kytiyu-tiyu.com>\n  <https://m.kytiyu-sports-games.com>\n  <https://m.kytiyu-sports-zh.com>\n  <https://m.kytiyu-sports-cn.com>\n  <https://m.cn-kytiyu-sports.com>\n  <https://m.zh-kytiyu-sports.com>\n  <https://m.game-kytiyu-sports.com>\n  <https://m.game-kytiyu-tiyu.com>\n  <https://m.online-kytiyu-tiyu.com>\n  <https://m.qiusu-speed.com>\n  <https://m.qiusu-zh.com>\n  <https://m.qiusu-web.com>\n  <https://m.qiusutiyu-game.com>\n  <https://m.qiusutiyu-online.com>\n  <https://m.qiususports-online.com>\n  <https://m.qiususports-game.com>\n  <https://m.sports-qiusutiyu.com>\n  <https://m.game-ballspeed.com>\n  <https://m.online-ballspeed.com>\n  <https://m.leyutiyu-zh.com>\n  <https://m.leyusports-zh.com>\n  <https://m.cn-leyutiyu.com>\n  <https://m.net-leyutiyu.com>\n  <https://m.leyuty ...
#     'reactions': {'url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io/issues/121812/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/kysports-cn/kytiyusports-cn.github.io/issues/121812/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None}},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z'},
#  {'id': '43881352229',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 6656432,
#    'login': 'lngarrett',
#    'display_login': 'lngarrett',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lngarrett',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6656432?'},
#   'repo': {'id': 85712676,
#    'name': 'bp2008/ui3',
#    'url': 'https://api.github.com/repos/bp2008/ui3'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/bp2008/ui3/issues/186',
#     'repository_url': 'https://api.github.com/repos/bp2008/ui3',
#     'labels_url': 'https://api.github.com/repos/bp2008/ui3/issues/186/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/bp2008/ui3/issues/186/comments',
#     'events_url': 'https://api.github.com/repos/bp2008/ui3/issues/186/events',
#     'html_url': 'https://github.com/bp2008/ui3/issues/186',
#     'id': 2647382594,
#     'node_id': 'I_kwDOBRvfJM6dy9pC',
#     'number': 186,
#     'title': 'Uncaught TypeError with Basic Auth: clipTimeline.getZoomScaler() undefined',
#     'user': {'login': 'lngarrett',
#      'id': 6656432,
#      'node_id': 'MDQ6VXNlcjY2NTY0MzI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6656432?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lngarrett',
#      'html_url': 'https://github.com/lngarrett',
#      'followers_url': 'https://api.github.com/users/lngarrett/followers',
#      'following_url': 'https://api.github.com/users/lngarrett/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lngarrett/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lngarrett/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lngarrett/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lngarrett/orgs',
#      'repos_url': 'https://api.github.com/users/lngarrett/repos',
#      'events_url': 'https://api.github.com/users/lngarrett/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lngarrett/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 19,
#     'created_at': '2024-11-10T16:05:18Z',
#     'updated_at': '2024-11-15T23:40:57Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'When using UI3 with Basic Authentication (instead of secure session tokens/form login), when returning to a browser tab after an extended period (several hours) the following error occurs intermittently. This is also usually accompanied by the UI hanging at "Checking Session Status".\r\n\r\nFor context, I use basic auth in order to properly integrate BI with a forward auth proxy. However, the issue occurs even when I directly connect to BI, bypassing the proxy.\r\n\r\n```\r\nUncaught TypeError: Cannot read properties of undefined (reading \'toFixed\')\r\nat https://[hostname]/ui3/ui3.js?v=277-5.9.9.3 [1452:132]\r\n```\r\n\r\n## Environment\r\n- Blue Iris Version: 5.9.9.3\r\n- UI3 Version: 277\r\n- Authentication Method: Basic Auth\r\n- Browser: Chrome 130.0.0.0 (Mobile), as well as Firefox desktop.\r\n- OS: Android 14 as well as Windows 11\r\n\r\n## Steps to Reproduce\r\n1. Configure UI3 to use Basic Authentication\r\n2. Load UI3 interface\r\n3. Error occurs intermittently when accessing timeline features\r\n\r\n## Other Observations\r\n- Issue only occurs with Basic Auth, not with secure session tokens/form login.\r\n- Error is intermittent, suggesting possible race condition in initialization. \r\n- Full browser refresh (CTRL + F5) temporarily resolves the issue, sometimes it takes a few refreshes. \r\n\r\n## Code Location\r\nThe error occurs in the timeline zoom scale settings comment function:\r\n```javascript\r\n{\r\n    key: "ui3_timeline_currentZoomScaleComment",\r\n    value: "",\r\n    inputType: "comment",\r\n    comment: function () { \r\n        return \'Current Zoom Scale: <span id="timelineCurrentZoomScaleComment">\' + \r\n               clipTimeline.getZoomScaler().toFixed(1) + \'</span>\'; \r\n    },\r\n    category: "Timeline"\r\n}',
#     'reactions': {'url': 'https://api.github.com/repos/bp2008/ui3/issues/186/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/bp2008/ui3/issues/186/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/bp2008/ui3/issues/comments/2480139533',
#     'html_url': 'https://github.com/bp2008/ui3/issues/186#issuecomment-2480139533',
#     'issue_url': 'https://api.github.com/repos/bp2008/ui3/issues/186',
#     'id': 2480139533,
#     'node_id': 'IC_kwDOBRvfJM6T0-0N',
#     'user': {'login': 'lngarrett',
#      'id': 6656432,
#      'node_id': 'MDQ6VXNlcjY2NTY0MzI=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6656432?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/lngarrett',
#      'html_url': 'https://github.com/lngarrett',
#      'followers_url': 'https://api.github.com/users/lngarrett/followers',
#      'following_url': 'https://api.github.com/users/lngarrett/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/lngarrett/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/lngarrett/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/lngarrett/subscriptions',
#      'organizations_url': 'https://api.github.com/users/lngarrett/orgs',
#      'repos_url': 'https://api.github.com/users/lngarrett/repos',
#      'events_url': 'https://api.github.com/users/lngarrett/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/lngarrett/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2024-11-15T23:40:55Z',
#     'updated_at': '2024-11-15T23:40:55Z',
#     'author_association': 'NONE',
#     'body': 'Fair enough, let me look a little closer at the response body directly and report back, it will likely be tomorrow. Thanks for your help!',
# ...
#       'releases_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/deployments',
#       'created_at': '2021-06-10T04:30:15Z',
#       'updated_at': '2023-01-31T18:57:08Z',
#       'pushed_at': '2024-11-15T23:40:54Z',
#       'git_url': 'git://github.com/GuruCICDCanary-Prod/CICDCanary.git',
#       'ssh_url': 'git@github.com:GuruCICDCanary-Prod/CICDCanary.git',
#       'clone_url': 'https://github.com/GuruCICDCanary-Prod/CICDCanary.git',
#       'svn_url': 'https://github.com/GuruCICDCanary-Prod/CICDCanary',
#       'homepage': None,
#       'size': 26,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 33,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 33,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'GuruCICDCanary-Prod:main',
#      'ref': 'main',
#      'sha': 'a90d36d686d2b71a3b4487499ac8a82fca34d2ec',
#      'user': {'login': 'GuruCICDCanary-Prod',
#       'id': 85654403,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1NjU0NDAz',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/85654403?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/GuruCICDCanary-Prod',
#       'html_url': 'https://github.com/GuruCICDCanary-Prod',
#       'followers_url': 'https://api.github.com/users/GuruCICDCanary-Prod/followers',
#       'following_url': 'https://api.github.com/users/GuruCICDCanary-Prod/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/GuruCICDCanary-Prod/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/GuruCICDCanary-Prod/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/GuruCICDCanary-Prod/subscriptions',
#       'organizations_url': 'https://api.github.com/users/GuruCICDCanary-Prod/orgs',
#       'repos_url': 'https://api.github.com/users/GuruCICDCanary-Prod/repos',
#       'events_url': 'https://api.github.com/users/GuruCICDCanary-Prod/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/GuruCICDCanary-Prod/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 375569685,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNzU1Njk2ODU=',
#       'name': 'CICDCanary',
#       'full_name': 'GuruCICDCanary-Prod/CICDCanary',
#       'private': False,
#       'owner': {'login': 'GuruCICDCanary-Prod',
#        'id': 85654403,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1NjU0NDAz',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/85654403?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/GuruCICDCanary-Prod',
#        'html_url': 'https://github.com/GuruCICDCanary-Prod',
#        'followers_url': 'https://api.github.com/users/GuruCICDCanary-Prod/followers',
#        'following_url': 'https://api.github.com/users/GuruCICDCanary-Prod/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/GuruCICDCanary-Prod/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/GuruCICDCanary-Prod/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/GuruCICDCanary-Prod/subscriptions',
#        'organizations_url': 'https://api.github.com/users/GuruCICDCanary-Prod/orgs',
#        'repos_url': 'https://api.github.com/users/GuruCICDCanary-Prod/repos',
#        'events_url': 'https://api.github.com/users/GuruCICDCanary-Prod/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/GuruCICDCanary-Prod/received_events',
#        'type': 'Organization',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/GuruCICDCanary-Prod/CICDCanary',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary',
#       'forks_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/forks',
#       'keys_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/teams',
#       'hooks_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/hooks',
#       'issue_events_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/events',
#       'assignees_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/tags',
#       'blobs_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/languages',
#       'stargazers_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/stargazers',
#       'contributors_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/contributors',
#       'subscribers_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/subscribers',
#       'subscription_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/subscription',
#       'commits_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/merges',
#       'archive_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/downloads',
#       'issues_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/deployments',
#       'created_at': '2021-06-10T04:30:15Z',
#       'updated_at': '2023-01-31T18:57:08Z',
#       'pushed_at': '2024-11-15T23:40:54Z',
#       'git_url': 'git://github.com/GuruCICDCanary-Prod/CICDCanary.git',
#       'ssh_url': 'git@github.com:GuruCICDCanary-Prod/CICDCanary.git',
#       'clone_url': 'https://github.com/GuruCICDCanary-Prod/CICDCanary.git',
#       'svn_url': 'https://github.com/GuruCICDCanary-Prod/CICDCanary',
#       'homepage': None,
#       'size': 26,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 33,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 33,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/pulls/120032'},
#      'html': {'href': 'https://github.com/GuruCICDCanary-Prod/CICDCanary/pull/120032'},
#      'issue': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/issues/120032'},
#      'comments': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/issues/120032/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/pulls/120032/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/pulls/120032/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/GuruCICDCanary-Prod/CICDCanary/statuses/dc59a8663acbc5d6bdab6a020c6655dba0f985ab'}},
#     'author_association': 'CONTRIBUTOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': True,
#     'rebaseable': True,
#     'mergeable_state': 'clean',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 152,
#     'deletions': 0,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z',
#   'org': {'id': 85654403,
#    'login': 'GuruCICDCanary-Prod',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/GuruCICDCanary-Prod',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/85654403?'}},
#  {'id': '43881352146',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 606402187,
#    'name': 'sws2apps/organized-app',
#    'url': 'https://api.github.com/repos/sws2apps/organized-app'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/dexie-4.0.10',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Organized is a secure, cross-platform, and user-friendly app for managing Jehovah’s Witnesses congregation life. It assists with schedules, service reports, upcoming assignments. Auto-fetch program from jw.org, autoassign program parts, export print files in one click, view useful stats and reports. It’s useful for everyone in a congregation!',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z',
#   'org': {'id': 95527156,
#    'login': 'sws2apps',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/sws2apps',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95527156?'}},
#  {'id': '43881352138',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 528536555,
#    'name': 'zavodil/near-nft-owners-list',
#    'url': 'https://api.github.com/repos/zavodil/near-nft-owners-list'},
#   'payload': {'repository_id': 528536555,
#    'push_id': 21241959938,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '679cfa319910f022c991267bcec1e3c6883ca00b',
#    'before': 'fab3da2464547958031ebdb333584db3ad4e7029',
#    'commits': [{'sha': '679cfa319910f022c991267bcec1e3c6883ca00b',
#      'author': {'email': 'zavodil@users.noreply.github.com',
#       'name': 'NFT Owners Updater'},
#      'message': 'NFT Owners fetching',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zavodil/near-nft-owners-list/commits/679cfa319910f022c991267bcec1e3c6883ca00b'}]},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z'},
#  {'id': '43881352133',
#   'type': 'PushEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 251668574,
#    'name': 'diegoazh/gmap-vue',
#    'url': 'https://api.github.com/repos/diegoazh/gmap-vue'},
#   'payload': {'repository_id': 251668574,
#    'push_id': 21241959953,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/npm_and_yarn/npm_and_yarn-8a5242b2ad',
#    'head': '71fdcd4f8c502790dacac0782098997eedbc5bcd',
#    'before': '7fc2bf8638420579b99810b12a88e693db5db799',
#    'commits': [{'sha': 'd289baa03c35a2cbeb6d95ef8946d663962fbbb4',
#      'author': {'email': 'semantic-release-bot@martynus.net',
#       'name': 'semantic-release-bot'},
#      'message': 'chore(v3): 2.1.3 [skip ci]\n\n## [2.1.3](https://github.com/diegoazh/gmap-vue/compare/gmv3_v2.1.2...gmv3_v2.1.3) (2024-11-15)\n\n### Bug Fixes\n\n* packages/documentation/package.json to reduce vulnerabilities ([#330](https://github.com/diegoazh/gmap-vue/issues/330)) ([2e2046f](https://github.com/diegoazh/gmap-vue/commit/2e2046fcfc4f7e88e86f39dcd72cc514781175fe))\n* packages/documentation/package.json to reduce vulnerabilities ([#332](https://github.com/diegoazh/gmap-vue/issues/332)) ([4b7b524](https://github.com/diegoazh/gmap-vue/commit/4b7b5244bc208c6495c6b5c4733d7fb84a38c099))\n* upgrade @docusaurus/core from 3.2.0 to 3.2.1 ([#326](https://github.com/diegoazh/gmap-vue/issues/326)) ([955c35b](https://github.com/diegoazh/gmap-vue/commit/955c35bca5913eebb80c3f96c519f582656d6bbb))\n* upgrade @docusaurus/preset-classic from 3.2.0 to 3.2.1 ([#325](https://github.com/diegoazh/gmap-vue/issues/325)) ([dc6ed1b](https://github.com/diegoazh/gmap-vue/commit/dc6ed1bc1f9cb411f955f98f6a6e03498d4e46af))',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/diegoazh/gmap-vue/commits/d289baa03c35a2cbeb6d95ef8946d663962fbbb4'},
#     {'sha': '71fdcd4f8c502790dacac0782098997eedbc5bcd',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'chore(deps): bump vue in the npm_and_yarn group across 1 directory\n\nBumps the npm_and_yarn group with 1 update in the / directory: [vue](https://github.com/vuejs/core).\n\n\nUpdates `vue` from 3.5.12 to 3.5.13\n- [Release notes](https://github.com/vuejs/core/releases)\n- [Changelog](https://github.com/vuejs/core/blob/main/CHANGELOG.md)\n- [Commits](https://github.com/vuejs/core/compare/v3.5.12...v3.5.13)\n\n---\nupdated-dependencies:\n- dependency-name: vue\n  dependency-type: direct:production\n  dependency-group: npm_and_yarn\n...\n\nSigned-off-by: dependabot[bot] <support@github.com>',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/diegoazh/gmap-vue/commits/71fdcd4f8c502790dacac0782098997eedbc5bcd'}]},
#   'public': True,
#   'created_at': '2024-11-15T23:40:57Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
    api_base_url = 'https://api.github.com'
    onwer = 'amzn'
    url = f'{api_base_url}/users/{onwer}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response =  requests.get(url,headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2024-10-28T21:35:35Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 357,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 357,
#   'open_issues': 3,
#   'watchers': 14,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2024-11-08T07:06:49Z',
#   'pushed_at': '2024-07-18T14:40:53Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 370,
#   'stargazers_count': 97,
#   'watchers_count': 97,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 28,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 28,
#   'watchers': 97,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 24,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 24,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2024-08-04T00:31:19Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1135,
#   'watchers_count': 1135,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1040,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1040,
#   'open_issues': 11,
#   'watchers': 1135,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2024-05-30T21:19:04Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 9,
#   'watchers_count': 9,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 4,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 4,
#   'open_issues': 0,
#   'watchers': 9,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 66,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2024-10-01T18:04:47Z',
#   'pushed_at': '2024-05-30T18:52:25Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 11,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
# ...
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 42,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 12,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 42,
#   'open_issues': 12,
#   'watchers': 48,
#   'default_branch': 'master'},
#  {'id': 27605347,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYwNTM0Nw==',
#   'name': 'amazon-pay-sdk-java',
#   'full_name': 'amzn/amazon-pay-sdk-java',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'description': ' Amazon Pay Java SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-09-09T14:17:34Z',
#   'pushed_at': '2024-08-10T17:28:22Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 58,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-09-17T15:30:38Z',
#   'pushed_at': '2024-05-14T13:04:33Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 877,
#   'stargazers_count': 208,
#   'watchers_count': 208,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 92,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 92,
#   'open_issues': 37,
#   'watchers': 208,
#   'default_branch': 'master'}]

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %%
# Função para ler o token do arquivo 
def ler_token(caminho_do_arquivo): 
    with open(caminho_do_arquivo, 'r') as file: 
        token = file.read().strip() 
        return token
    
access_token = ler_token('token.txt')

headers={'Authorization': 'Bearer ' + access_token,
         'X-GitHub-Api-Version': '2022-11-28'}
# Out:
# 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
# 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

# %% [markdown]
# ### Paginando os repositórios

# %%
api_base_url = 'https://api.github.com'
onwer = 'amzn'
url = f'{api_base_url}/users/{onwer}/repos'

url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
repos_list = []
for page_num in range(1, 6):
    try:
        url_page = f'{url}?page={page_num}'
        response = requests.get(url_page, headers=headers)
        repos_list.append(response.json())
    except: 
        repos_list.append(None)

# %%
repos_list
# Out:
# [[{'id': 171339259,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#    'name': '.github',
#    'full_name': 'amzn/.github',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/.github',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/.github',
#    'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/.github/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#    'created_at': '2019-02-18T18:59:22Z',
#    'updated_at': '2024-10-28T21:35:35Z',
#    'pushed_at': '2024-10-18T22:23:05Z',
#    'git_url': 'git://github.com/amzn/.github.git',
#    'ssh_url': 'git@github.com:amzn/.github.git',
#    'clone_url': 'https://github.com/amzn/.github.git',
#    'svn_url': 'https://github.com/amzn/.github',
#    'homepage': None,
#    'size': 24,
#    'stargazers_count': 14,
#    'watchers_count': 14,
#    'language': None,
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 357,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': None,
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 357,
#    'open_issues': 3,
#    'watchers': 14,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 492978607,
#    'node_id': 'R_kgDOHWJBrw',
#    'name': 'ads-advanced-tools-docs',
#    'full_name': 'amzn/ads-advanced-tools-docs',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#    'created_at': '2022-05-16T19:49:03Z',
#    'updated_at': '2024-11-08T07:06:49Z',
#    'pushed_at': '2024-07-18T14:40:53Z',
#    'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#    'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#    'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#    'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#    'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#    'size': 370,
#    'stargazers_count': 97,
#    'watchers_count': 97,
#    'language': 'Jupyter Notebook',
#    'has_issues': True,
#    'has_projects': False,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': True,
#    'forks_count': 32,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 28,
#    'license': {'key': 'mit-0',
#     'name': 'MIT No Attribution',
#     'spdx_id': 'MIT-0',
#     'url': 'https://api.github.com/licenses/mit-0',
#     'node_id': 'MDc6TGljZW5zZTQx'},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#    'visibility': 'public',
#    'forks': 32,
#    'open_issues': 28,
#    'watchers': 97,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 674005216,
#    'node_id': 'R_kgDOKCyA4A',
#    'name': 'ads-pao-amznjs-gtm-template',
#    'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#    'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#    'created_at': '2023-08-02T23:41:56Z',
#    'updated_at': '2024-09-05T08:32:25Z',
#    'pushed_at': '2024-06-03T16:53:23Z',
#    'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#    'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#    'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#    'homepage': None,
#    'size': 165,
#    'stargazers_count': 3,
#    'watchers_count': 3,
#    'language': 'Smarty',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 0,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 0,
#    'open_issues': 0,
#    'watchers': 3,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 41117941,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#    'name': 'alexa-coho',
#    'full_name': 'amzn/alexa-coho',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-coho',
#    'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-coho',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#    'created_at': '2015-08-20T20:42:31Z',
#    'updated_at': '2024-07-11T01:03:40Z',
#    'pushed_at': '2023-04-01T08:35:29Z',
#    'git_url': 'git://github.com/amzn/alexa-coho.git',
#    'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#    'clone_url': 'https://github.com/amzn/alexa-coho.git',
#    'svn_url': 'https://github.com/amzn/alexa-coho',
#    'homepage': None,
#    'size': 209,
#    'stargazers_count': 63,
#    'watchers_count': 63,
#    'language': 'JavaScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 24,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 4,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 24,
#    'open_issues': 4,
#    'watchers': 63,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 39471546,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#    'name': 'alexa-skills-kit-js',
#    'full_name': 'amzn/alexa-skills-kit-js',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#    'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#    'created_at': '2015-07-21T21:46:48Z',
#    'updated_at': '2024-08-04T00:31:19Z',
#    'pushed_at': '2020-10-01T06:10:20Z',
#    'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#    'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#    'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#    'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#    'homepage': 'http://developer.amazon.com/ask',
#    'size': 8827,
#    'stargazers_count': 1135,
#    'watchers_count': 1135,
#    'language': None,
#    'has_issues': False,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 1040,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 11,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 1040,
#    'open_issues': 11,
#    'watchers': 1135,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 495519526,
#    'node_id': 'R_kgDOHYkHJg',
#    'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#    'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'description': None,
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#    'created_at': '2022-05-23T17:59:56Z',
#    'updated_at': '2024-05-30T21:19:04Z',
#    'pushed_at': '2022-05-23T21:20:34Z',
#    'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#    'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#    'homepage': None,
#    'size': 16,
#    'stargazers_count': 9,
#    'watchers_count': 9,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 4,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 0,
#    'license': {'key': 'other',
#     'name': 'Other',
#     'spdx_id': 'NOASSERTION',
#     'url': None,
#     'node_id': 'MDc6TGljZW5zZTA='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 4,
#    'open_issues': 0,
#    'watchers': 9,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 61315875,
#    'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#    'name': 'amazon-advertising-api-php-sdk',
#    'full_name': 'amzn/amazon-advertising-api-php-sdk',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#    'created_at': '2016-06-16T18:16:46Z',
#    'updated_at': '2024-09-14T07:43:36Z',
#    'pushed_at': '2020-09-20T17:25:48Z',
#    'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#    'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#    'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#    'homepage': '',
#    'size': 49,
#    'stargazers_count': 93,
#    'watchers_count': 93,
#    'language': 'PHP',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 66,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 14,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 66,
#    'open_issues': 14,
#    'watchers': 93,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 429297502,
#    'node_id': 'R_kgDOGZaPXg',
#    'name': 'amazon-codeguru-profiler-for-spark',
#    'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#    'description': 'A Spark plugin for CPU and memory profiling',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#    'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
# ...
#    'git_tags_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/tiny-attribution-generator/deployments',
#    'created_at': '2018-08-06T15:07:34Z',
#    'updated_at': '2023-07-15T20:02:15Z',
#    'pushed_at': '2020-12-23T22:35:18Z',
#    'git_url': 'git://github.com/amzn/tiny-attribution-generator.git',
#    'ssh_url': 'git@github.com:amzn/tiny-attribution-generator.git',
#    'clone_url': 'https://github.com/amzn/tiny-attribution-generator.git',
#    'svn_url': 'https://github.com/amzn/tiny-attribution-generator',
#    'homepage': 'https://www.npmjs.com/package/tiny-attribution-generator',
#    'size': 376,
#    'stargazers_count': 20,
#    'watchers_count': 20,
#    'language': 'TypeScript',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': False,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 15,
#    'mirror_url': None,
#    'archived': True,
#    'disabled': False,
#    'open_issues_count': 1,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': ['licensing', 'nodejs', 'open-source-tooling'],
#    'visibility': 'public',
#    'forks': 15,
#    'open_issues': 1,
#    'watchers': 20,
#    'default_branch': 'master',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 431462375,
#    'node_id': 'R_kgDOGbeX5w',
#    'name': 'trans-encoder',
#    'full_name': 'amzn/trans-encoder',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/trans-encoder',
#    'description': 'Trans-Encoder: Unsupervised sentence-pair modelling through self- and mutual-distillations',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/trans-encoder',
#    'forks_url': 'https://api.github.com/repos/amzn/trans-encoder/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/trans-encoder/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/trans-encoder/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/trans-encoder/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/trans-encoder/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/trans-encoder/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/trans-encoder/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/trans-encoder/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/trans-encoder/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/trans-encoder/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/trans-encoder/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/trans-encoder/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/trans-encoder/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/trans-encoder/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/trans-encoder/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/trans-encoder/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/trans-encoder/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/trans-encoder/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/trans-encoder/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/trans-encoder/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/trans-encoder/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/trans-encoder/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/trans-encoder/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/trans-encoder/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/trans-encoder/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/trans-encoder/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/trans-encoder/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/trans-encoder/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/trans-encoder/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/trans-encoder/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/trans-encoder/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/trans-encoder/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/trans-encoder/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/trans-encoder/deployments',
#    'created_at': '2021-11-24T11:44:32Z',
#    'updated_at': '2024-09-24T10:03:38Z',
#    'pushed_at': '2024-05-30T18:51:20Z',
#    'git_url': 'git://github.com/amzn/trans-encoder.git',
#    'ssh_url': 'git@github.com:amzn/trans-encoder.git',
#    'clone_url': 'https://github.com/amzn/trans-encoder.git',
#    'svn_url': 'https://github.com/amzn/trans-encoder',
#    'homepage': '',
#    'size': 45,
#    'stargazers_count': 133,
#    'watchers_count': 133,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 16,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 16,
#    'open_issues': 3,
#    'watchers': 133,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}},
#   {'id': 638205169,
#    'node_id': 'R_kgDOJgo88Q',
#    'name': 'user-satisfaction-modeling',
#    'full_name': 'amzn/user-satisfaction-modeling',
#    'private': False,
#    'owner': {'login': 'amzn',
#     'id': 8594673,
#     'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/amzn',
#     'html_url': 'https://github.com/amzn',
#     'followers_url': 'https://api.github.com/users/amzn/followers',
#     'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#     'organizations_url': 'https://api.github.com/users/amzn/orgs',
#     'repos_url': 'https://api.github.com/users/amzn/repos',
#     'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/amzn/received_events',
#     'type': 'Organization',
#     'user_view_type': 'public',
#     'site_admin': False},
#    'html_url': 'https://github.com/amzn/user-satisfaction-modeling',
#    'description': 'Codebase for the paper "Schema-guided User Satisfaction Modeling for Task-oriented Dialogues"',
#    'fork': False,
#    'url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling',
#    'forks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/forks',
#    'keys_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/keys{/key_id}',
#    'collaborators_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/collaborators{/collaborator}',
#    'teams_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/teams',
#    'hooks_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/hooks',
#    'issue_events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/events{/number}',
#    'events_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/events',
#    'assignees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/assignees{/user}',
#    'branches_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/branches{/branch}',
#    'tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/tags',
#    'blobs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/blobs{/sha}',
#    'git_tags_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/tags{/sha}',
#    'git_refs_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/refs{/sha}',
#    'trees_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/trees{/sha}',
#    'statuses_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/statuses/{sha}',
#    'languages_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/languages',
#    'stargazers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/stargazers',
#    'contributors_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contributors',
#    'subscribers_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscribers',
#    'subscription_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/subscription',
#    'commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/commits{/sha}',
#    'git_commits_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/git/commits{/sha}',
#    'comments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/comments{/number}',
#    'issue_comment_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues/comments{/number}',
#    'contents_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/contents/{+path}',
#    'compare_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/compare/{base}...{head}',
#    'merges_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/merges',
#    'archive_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/{archive_format}{/ref}',
#    'downloads_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/downloads',
#    'issues_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/issues{/number}',
#    'pulls_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/pulls{/number}',
#    'milestones_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/milestones{/number}',
#    'notifications_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/notifications{?since,all,participating}',
#    'labels_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/labels{/name}',
#    'releases_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/releases{/id}',
#    'deployments_url': 'https://api.github.com/repos/amzn/user-satisfaction-modeling/deployments',
#    'created_at': '2023-05-09T09:52:46Z',
#    'updated_at': '2024-10-09T14:18:49Z',
#    'pushed_at': '2024-10-09T14:18:45Z',
#    'git_url': 'git://github.com/amzn/user-satisfaction-modeling.git',
#    'ssh_url': 'git@github.com:amzn/user-satisfaction-modeling.git',
#    'clone_url': 'https://github.com/amzn/user-satisfaction-modeling.git',
#    'svn_url': 'https://github.com/amzn/user-satisfaction-modeling',
#    'homepage': '',
#    'size': 25,
#    'stargazers_count': 11,
#    'watchers_count': 11,
#    'language': 'Python',
#    'has_issues': True,
#    'has_projects': True,
#    'has_downloads': True,
#    'has_wiki': True,
#    'has_pages': False,
#    'has_discussions': False,
#    'forks_count': 3,
#    'mirror_url': None,
#    'archived': False,
#    'disabled': False,
#    'open_issues_count': 3,
#    'license': {'key': 'apache-2.0',
#     'name': 'Apache License 2.0',
#     'spdx_id': 'Apache-2.0',
#     'url': 'https://api.github.com/licenses/apache-2.0',
#     'node_id': 'MDc6TGljZW5zZTI='},
#    'allow_forking': True,
#    'is_template': False,
#    'web_commit_signoff_required': False,
#    'topics': [],
#    'visibility': 'public',
#    'forks': 3,
#    'open_issues': 3,
#    'watchers': 11,
#    'default_branch': 'main',
#    'permissions': {'admin': False,
#     'maintain': False,
#     'push': False,
#     'triage': False,
#     'pull': True}}]]

# %%
len(repos_list)
# Out:
# 5

# %%
len(repos_list[0])
# Out:
# 30

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %%
repos_list[0][2]['name']
# Out:
# 'ads-pao-amznjs-gtm-template'

# %%
repos_names = []
for page in repos_list:
    for repo in page:
        repos_names.append(repo['name'])

# %%
repos_names
# Out:
# ['.github',
#  'ads-advanced-tools-docs',
#  'ads-pao-amznjs-gtm-template',
#  'alexa-coho',
#  'alexa-skills-kit-js',
#  'amazon-ads-advertiser-audience-normalization-sdk-py',
#  'amazon-advertising-api-php-sdk',
#  'amazon-codeguru-profiler-for-spark',
#  'amazon-frustration-free-setup-certification-tool',
#  'amazon-hub-counter-api-docs',
#  'amazon-hub-counter-api-samples',
#  'amazon-hub-counter-sdk-java',
#  'amazon-hub-support',
#  'amazon-instant-access-sdk-java',
#  'amazon-instant-access-sdk-net',
#  'amazon-instant-access-sdk-php',
#  'amazon-instant-access-sdk-ruby',
#  'amazon-launcher-integration-cordova-plugin',
#  'amazon-marketing-stream-examples',
#  'amazon-mcf-plugin-for-magento-1',
#  'amazon-multi-token-completion',
#  'amazon-nearest-neighbor-through-ecc',
#  'amazon-pay-api-sdk-dotnet',
#  'amazon-pay-api-sdk-java',
#  'amazon-pay-api-sdk-nodejs',
#  'amazon-pay-api-sdk-php',
#  'amazon-pay-api-sdk-ruby',
#  'amazon-pay-sdk-csharp',
#  'amazon-pay-sdk-java',
#  'amazon-pay-sdk-php',
#  'amazon-pay-sdk-python',
#  'amazon-pay-sdk-ruby',
#  'amazon-pay-sdk-samples',
#  'amazon-payment-files-tools',
#  'amazon-payments-magento-2-plugin',
#  'amazon-ray',
#  'amazon-s3-gst-plugin',
#  'amazon-sidewalk-android-samples',
#  'amazon-sidewalk-ios-samples',
#  'amazon-succinct-doc-representation',
#  'amazon-template-library',
#  'amazon-weak-ner-needle',
#  'amigitenough',
#  'amzn-drivers',
#  'amzn-ec2-ena-utilities',
#  'armbench',
#  'auction-gym',
#  'augment-the-pairs-wacv2024',
#  'autotrail',
#  'aws-apigateway-client-lib',
#  'aws-sigv4-signing-samples',
#  'awsssmchaosrunner',
#  'basis-point-sets',
#  'BayesPE',
#  'buy-with-prime-automate-tenant-validation',
#  'buy-with-prime-cdk-constructs',
#  'buy-with-prime-event-accelerator',
#  'buy-with-prime-monitoring-sample-cdk',
#  'buy-with-prime-oauth-handler-ec2',
#  'buy-with-prime-saas-integration',
#  'chalet-charging-location-for-electric-trucks',
#  'computer-vision-basics-in-microsoft-excel',
#  'confident-sinkhorn-allocation',
#  'convolutional-handwriting-gan',
#  'cosearcher',
#  'credence-to-causal-estimation',
#  'data-jack-knife',
#  'debiased-balanced-interleaving',
#  'differential-privacy-bayesian-optimization',
#  'distance-assistant',
#  'drs-sample-android-app',
#  'drs-sample-ios-app',
#  'emukit-playground',
#  'eslint-plugin-no-date-parsing',
#  'exoplayer-amazon-port',
#  'explainable-text-vqa',
#  'extremely-efficient-query-encoder',
#  'faithful-data2text-cycle-training',
#  'fashion-attribute-disentanglement',
#  'fire-app-builder',
#  'firetv-sample-touch-app',
#  'ftv-integration-sdk-sample-app',
#  'ftv-livetv-sample-tv-app',
#  'gameon-sample-game-unity',
#  'gameon-starter-kit-unity',
#  'git-commit-template',
#  'glad',
#  'golang-gitoperations',
#  'halo-third-party-sdk-for-java',
#  'halo-third-party-sdk-for-node-js',
#  'halo-third-party-sdk-for-python',
#  'hawktracer',
#  'image-misspell-coling2020',
#  'image-to-recipe-transformers',
#  'informative-diverse-hard-negative-sampling',
#  'ion-cascading-config',
#  'ion-object-mapper-dotnet',
#  'jekyll-doc-project',
#  'kotlin-inject-anvil',
#  'kqr',
#  'login-with-amazon-oscommerce',
#  'login-with-amazon-wordpress',
#  'media3-external-port',
#  'merlin-on-demand-callgraph',
#  'metalearn-leap',
#  'milan',
#  'mrc-net-6d-pose',
#  'multiconer-baseline',
#  'multilingual-keyphrase-generation',
#  'multimodal-affinities',
#  'MXFusion',
#  'nimbus-jose-jwt_aws-kms-extension',
#  'node-jose_aws-kms-extension',
#  'openapi-swift-code-generate',
#  'orthogonal-additive-gaussian-processes',
#  'oss-attribution-builder',
#  'oss-contribution-tracker',
#  'oss-dashboard',
#  'pecos',
#  'pretraining-or-self-training',
#  'python-jose_aws-kms-extension',
#  'rdma-core',
#  'refuel-open-domain-qa',
#  'rete-thewebconf-2022',
#  'rheoceros',
#  'robotiq-gripper-interface',
#  'sample-fire-tv-app-video-skill',
#  'selling-partner-api-docs',
#  'selling-partner-api-models',
#  'selling-partner-api-samples',
#  'seqzero',
#  'service-model-swift-code-generate',
#  'sketch-constructor',
#  'smoke-aws',
#  'smoke-aws-credentials',
#  'smoke-aws-generate',
#  'smoke-aws-support',
#  'smoke-dynamodb',
#  'smoke-framework',
#  'smoke-framework-application-generate',
#  'smoke-framework-examples',
#  'smoke-http',
#  'sparse-vqvae',
#  'ss-aga-kgc',
#  'sto-transformer',
#  'style-dictionary',
#  'supply-chain-simulation-environment',
#  'tiny-attribution-generator',
#  'trans-encoder',
#  'user-satisfaction-modeling']

# %%
len(repos_names)
# Out:
# 150

# %% [markdown]
# ### Linguagens dos repositórios

# %%
repos_list[1][1]['language']
# Out:
# 'Ruby'

# %%
repos_languages = []
for page in repos_list:
    for repo in page:
        repos_languages.append(repo['language'])

# %%
repos_languages
# Out:
# [None,
#  'Jupyter Notebook',
#  'Smarty',
#  'JavaScript',
#  None,
#  'Python',
#  'PHP',
#  'Java',
#  'Python',
#  'CSS',
#  'Java',
#  'Java',
#  'PowerShell',
#  'Java',
#  'C#',
#  'PHP',
#  'Ruby',
#  'JavaScript',
#  'Python',
#  'PHP',
#  'Python',
#  'Jupyter Notebook',
#  'C#',
#  'Java',
#  'JavaScript',
#  'PHP',
#  'Ruby',
#  'C#',
#  'Java',
#  'PHP',
#  'Python',
#  'Ruby',
#  'PHP',
#  'Kotlin',
#  'PHP',
#  'Python',
#  'C',
#  None,
#  'Swift',
#  'Python',
#  'C++',
#  'Python',
#  'Go',
#  'C',
#  'Python',
#  'Python',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  None,
#  'Java',
#  'Kotlin',
#  'Python',
#  'Python',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  'TypeScript',
#  'JavaScript',
#  'TypeScript',
#  'Python',
#  None,
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Jupyter Notebook',
#  'Python',
#  'Python',
#  'Java',
#  'Objective-C',
#  'JavaScript',
#  'TypeScript',
#  'Java',
#  None,
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'Java',
#  'Kotlin',
#  'Java',
#  'C#',
#  'C#',
#  'JavaScript',
#  'JavaScript',
#  'Go',
#  'Java',
#  'TypeScript',
#  'Python',
#  'C++',
#  None,
#  'Python',
#  'Python',
#  'Java',
#  'C#',
#  'HTML',
#  'Kotlin',
#  None,
#  'PHP',
#  'PHP',
#  None,
#  'JavaScript',
#  'Python',
#  'Scala',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Python',
#  'Java',
#  'TypeScript',
#  'Swift',
#  'Python',
#  'TypeScript',
#  'TypeScript',
#  'Ruby',
#  'Python',
#  'Python',
#  'Python',
#  'C',
#  'Python',
#  'Python',
#  'Python',
#  'C++',
#  'Java',
#  None,
#  'Mustache',
#  'Java',
#  'Python',
#  'Swift',
#  'JavaScript',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Swift',
#  'Python',
#  'Python',
#  'Python',
#  'JavaScript',
#  'Python',
#  'TypeScript',
#  'Python',
#  'Python']

# %%
len(repos_languages)
# Out:
# 150

# %% [markdown]
# ### Criando um DataFrame

# %%
import pandas as pd

# %%
dados_amz = pd.DataFrame()
dados_amz['repository_name'] = repos_names
dados_amz['language'] = repos_languages

# %%
dados_amz
# Out:
#                          repository_name          language
# 0                                .github              None
# 1                ads-advanced-tools-docs  Jupyter Notebook
# 2            ads-pao-amznjs-gtm-template            Smarty
# 3                             alexa-coho        JavaScript
# 4                    alexa-skills-kit-js              None
# ..                                   ...               ...
# 145                     style-dictionary        JavaScript
# 146  supply-chain-simulation-environment            Python
# 147           tiny-attribution-generator        TypeScript
# 148                        trans-encoder            Python
# 149           user-satisfaction-modeling            Python
#
# [150 rows x 2 columns]

# %% [markdown]
# Salvando o DataFrame

# %%
dados_amz.to_csv('amazon.csv')

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %% [markdown]
# ### Formato do arquivo

# %% [markdown]
# ### Upload de arquivo com PUT
