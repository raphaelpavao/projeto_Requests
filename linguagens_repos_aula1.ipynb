# %% [markdown]
# ## Conhecendo a requests

# %% [markdown]
# ### Primeira requisição

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# ### Explorando a biblioteca

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"43878394017","type":"PullRequestEvent","actor":{"id":4598641,"login":"carlrobert","display_login":"carlrobert","gravatar_id":"","url":"https://api.github.com/users/carlrobert","avatar_url":"https://avatars.githubusercontent.com/u/4598641?"},"repo":{"id":886276549,"name":"carlrobert/double-switch","url":"https://api.github.com/repos/carlrobert/double-switch"},"payload":{"action":"opened","number":2,"pull_request":{"url":"https://api.github.com/repos/carlrobert/double-switch/pulls/2","id":2182572987,"node_id":"PR_kwDONNOBxc6CF2u7","html_url":"https://github.com/carlrobert/double-switch/pull/2","diff_url":"https://github.com/carlrobert/double-switch/pull/2.diff","patch_url":"https://github.com/carlrobert/double-switch/pull/2.patch","issue_url":"https://api.github.com/repos/carlrobert/double-switch/issues/2","number":2,"state":"open","locked":false,"title":"Master","user":{"login":"carlrobert","id":4598641,"node_id":"MDQ6VXNlcjQ1OTg2NDE=","avatar_url":"https://avatars.githubusercontent.com/u/4598641?v=4","gravatar_id":"","url":"https://api.github.com/users/carlrobert","html_url":"https://github.com/carlrobert","followers_url":"https://api.github.com/users/carlrobert/followers","following_url":"https://api.github.com/users/carlrobert/following{/other_user}","gists_url":"https://api.github.com/users/carlrobert/gists{/gist_id}","starred_url":"https://api.github.com/users/carlrobert/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/carlrobert/subscriptions","organizations_url":"https://api.github.com/users/carlrobert/orgs","repos_url":"https://api.github.com/users/carlrobert/repos","events_url":"https://api.github.com/users/carlrobert/events{/privacy}","received_events_url":"https://api.github.com/users/carlrobert/received_events","type":"User","user_view_type":"public","site_admin":false},"body":null,"created_at":"2024-11-15T21:05:37Z","updated_at":"2024-11-15T21:05:37Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/carlrobert/double-switch/pulls/2/commits","review_comments_url":"https://api.github.com/repos/carlrobert/double-switch/pulls/2/comments","review_comment_url":"https://api.github.com/repos/carlrobert/double-switch/pulls/comments{/number}","comments_url":"https://api.github.com/repos/carlrobert/double-switch/issues/2/comments","statuses_url":"https://api.github.com/repos/carlrobert/double-switch/statuses/c850bb868e0159dbed7f97218d2b19db3dad8616","head":{"label":"carlrobert:master","ref":"master","sha":"c850bb868e0159dbed7f97218d2b19db3dad8616","user":{"login":"carlrobert","id":4598641,"node_id":"MDQ6VXNlcjQ1OTg2NDE=","avatar_url":"https://avatars.githubusercontent.com/u/4598641?v=4","gravatar_id":"","url":"https://api.github.com/users/carlrobert","html_url":"https://github.com/carlrobert","followers_url":"https://api.github.com/users/carlrobert/followers","following_url":"https://api.github.com/users/carlrobert/following{/other_user}","gists_url":"https://api.github.com/users/carlrobert/gists{/gist_id}","starred_url":"https://api.github.com/users/carlrobert/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/carlrobert/subscriptions","organizations_url":"https://api.github.com/users/carlrobert/orgs","repos_url":"https://api.github.com/users/carlrobert/repos","events_url":"https://api.github.com/users/carlrobert/events{/privacy}","received_events_url":"https://api.github.com/users/carlrobert/received_events","type":"User","user_view_type":"public","site_admin":false},"repo":{"id":886276549,"node_id":"R_kgDONNOBxQ","name":"double-switch","full_name":"carlrobert/double-switch","private":false,"owner":{"login":"carlrobert","id":4598641,"node_id":"MDQ6VXNlcjQ1OTg2NDE=","avatar_url":"https://avatars.githubusercontent.com/u/4598641?v=4","gravatar_id":"","url":"https://api.github.com/users/carlrobert","ht ...

# %%
r.json()
# Out:
# [{'id': '43878394017',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 4598641,
#    'login': 'carlrobert',
#    'display_login': 'carlrobert',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/carlrobert',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4598641?'},
#   'repo': {'id': 886276549,
#    'name': 'carlrobert/double-switch',
#    'url': 'https://api.github.com/repos/carlrobert/double-switch'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/carlrobert/double-switch/pulls/2',
#     'id': 2182572987,
#     'node_id': 'PR_kwDONNOBxc6CF2u7',
#     'html_url': 'https://github.com/carlrobert/double-switch/pull/2',
#     'diff_url': 'https://github.com/carlrobert/double-switch/pull/2.diff',
#     'patch_url': 'https://github.com/carlrobert/double-switch/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/carlrobert/double-switch/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': 'Master',
#     'user': {'login': 'carlrobert',
#      'id': 4598641,
#      'node_id': 'MDQ6VXNlcjQ1OTg2NDE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4598641?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/carlrobert',
#      'html_url': 'https://github.com/carlrobert',
#      'followers_url': 'https://api.github.com/users/carlrobert/followers',
#      'following_url': 'https://api.github.com/users/carlrobert/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/carlrobert/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/carlrobert/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/carlrobert/subscriptions',
#      'organizations_url': 'https://api.github.com/users/carlrobert/orgs',
#      'repos_url': 'https://api.github.com/users/carlrobert/repos',
#      'events_url': 'https://api.github.com/users/carlrobert/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/carlrobert/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'body': None,
#     'created_at': '2024-11-15T21:05:37Z',
#     'updated_at': '2024-11-15T21:05:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/carlrobert/double-switch/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/carlrobert/double-switch/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/carlrobert/double-switch/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/carlrobert/double-switch/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/carlrobert/double-switch/statuses/c850bb868e0159dbed7f97218d2b19db3dad8616',
#     'head': {'label': 'carlrobert:master',
#      'ref': 'master',
#      'sha': 'c850bb868e0159dbed7f97218d2b19db3dad8616',
#      'user': {'login': 'carlrobert',
#       'id': 4598641,
#       'node_id': 'MDQ6VXNlcjQ1OTg2NDE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/4598641?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/carlrobert',
#       'html_url': 'https://github.com/carlrobert',
#       'followers_url': 'https://api.github.com/users/carlrobert/followers',
#       'following_url': 'https://api.github.com/users/carlrobert/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/carlrobert/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/carlrobert/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/carlrobert/subscriptions',
#       'organizations_url': 'https://api.github.com/users/carlrobert/orgs',
#       'repos_url': 'https://api.github.com/users/carlrobert/repos',
#       'events_url': 'https://api.github.com/users/carlrobert/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/carlrobert/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 886276549,
#       'node_id': 'R_kgDONNOBxQ',
#       'name': 'double-switch',
#       'full_name': 'carlrobert/double-switch',
#       'private': False,
#       'owner': {'login': 'carlrobert',
#        'id': 4598641,
#        'node_id': 'MDQ6VXNlcjQ1OTg2NDE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/4598641?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/carlrobert',
#        'html_url': 'https://github.com/carlrobert',
#        'followers_url': 'https://api.github.com/users/carlrobert/followers',
#        'following_url': 'https://api.github.com/users/carlrobert/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/carlrobert/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/carlrobert/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/carlrobert/subscriptions',
#        'organizations_url': 'https://api.github.com/users/carlrobert/orgs',
#        'repos_url': 'https://api.github.com/users/carlrobert/repos',
#        'events_url': 'https://api.github.com/users/carlrobert/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/carlrobert/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/carlrobert/double-switch',
#       'description': 'Obsidian plugin for switching themes when toggling dark/light mode',
#       'fork': False,
#       'url': 'https://api.github.com/repos/carlrobert/double-switch',
#       'forks_url': 'https://api.github.com/repos/carlrobert/double-switch/forks',
#       'keys_url': 'https://api.github.com/repos/carlrobert/double-switch/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/carlrobert/double-switch/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/carlrobert/double-switch/teams',
#       'hooks_url': 'https://api.github.com/repos/carlrobert/double-switch/hooks',
#       'issue_events_url': 'https://api.github.com/repos/carlrobert/double-switch/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/carlrobert/double-switch/events',
#       'assignees_url': 'https://api.github.com/repos/carlrobert/double-switch/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/carlrobert/double-switch/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/carlrobert/double-switch/tags',
#       'blobs_url': 'https://api.github.com/repos/carlrobert/double-switch/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/carlrobert/double-switch/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/carlrobert/double-switch/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/carlrobert/double-switch/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/carlrobert/double-switch/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/carlrobert/double-switch/languages',
#       'stargazers_url': 'https://api.github.com/repos/carlrobert/double-switch/stargazers',
#       'contributors_url': 'https://api.github.com/repos/carlrobert/double-switch/contributors',
#       'subscribers_url': 'https://api.github.com/repos/carlrobert/double-switch/subscribers',
#       'subscription_url': 'https://api.github.com/repos/carlrobert/double-switch/subscription',
#       'commits_url': 'https://api.github.com/repos/carlrobert/double-switch/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/carlrobert/double-switch/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/carlrobert/double-switch/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/carlrobert/double-switch/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/carlrobert/double-switch/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/carlrobert/double-switch/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/carlrobert/double-switch/merges',
#       'archive_url': 'https://api.github.com/repos/carlrobert/double-switch/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/carlrobert/double-switch/downloads',
#       'issues_url': 'https://api.github.com/repos/carlrobert/double-switch/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/carlrobert/double-switch/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/carlrobert/double-switch/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/carlrobert/double-switch/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/carlrobert/double-switch/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/carlrobert/double-switch/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/carlrobert/double-switch/deployments',
#       'created_at': '2024-11-10T16:45:22Z',
#       'updated_at': '2024-11-15T20:36:49Z',
#       'pushed_at': '2024-11-15T21:05:06Z',
#       'git_url': 'git://github.com/carlrobert/double-switch.git',
#       'ssh_url': 'git@github.com:carlrobert/double-switch.git',
#       'clone_url': 'https://github.com/carlrobert/double-switch.git',
#       'svn_url': 'https://github.com/carlrobert/double-switch',
#       'homepage': None,
#       'size': 74,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'carlrobert:main',
#      'ref': 'main',
#      'sha': '1a634f861930f8137e06488c1871a48692475e5b',
#      'user': {'login': 'carlrobert',
#       'id': 4598641,
#       'node_id': 'MDQ6VXNlcjQ1OTg2NDE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/4598641?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/carlrobert',
#       'html_url': 'https://github.com/carlrobert',
#       'followers_url': 'https://api.github.com/users/carlrobert/followers',
#       'following_url': 'https://api.github.com/users/carlrobert/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/carlrobert/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/carlrobert/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/carlrobert/subscriptions',
#       'organizations_url': 'https://api.github.com/users/carlrobert/orgs',
#       'repos_url': 'https://api.github.com/users/carlrobert/repos',
#       'events_url': 'https://api.github.com/users/carlrobert/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/carlrobert/received_events',
#       'type': 'User',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'repo': {'id': 886276549,
#       'node_id': 'R_kgDONNOBxQ',
#       'name': 'double-switch',
#       'full_name': 'carlrobert/double-switch',
#       'private': False,
#       'owner': {'login': 'carlrobert',
#        'id': 4598641,
#        'node_id': 'MDQ6VXNlcjQ1OTg2NDE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/4598641?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/carlrobert',
#        'html_url': 'https://github.com/carlrobert',
#        'followers_url': 'https://api.github.com/users/carlrobert/followers',
#        'following_url': 'https://api.github.com/users/carlrobert/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/carlrobert/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/carlrobert/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/carlrobert/subscriptions',
#        'organizations_url': 'https://api.github.com/users/carlrobert/orgs',
#        'repos_url': 'https://api.github.com/users/carlrobert/repos',
#        'events_url': 'https://api.github.com/users/carlrobert/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/carlrobert/received_events',
#        'type': 'User',
#        'user_view_type': 'public',
#        'site_admin': False},
#       'html_url': 'https://github.com/carlrobert/double-switch',
#       'description': 'Obsidian plugin for switching themes when toggling dark/light mode',
#       'fork': False,
#       'url': 'https://api.github.com/repos/carlrobert/double-switch',
#       'forks_url': 'https://api.github.com/repos/carlrobert/double-switch/forks',
#       'keys_url': 'https://api.github.com/repos/carlrobert/double-switch/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/carlrobert/double-switch/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/carlrobert/double-switch/teams',
#       'hooks_url': 'https://api.github.com/repos/carlrobert/double-switch/hooks',
#       'issue_events_url': 'https://api.github.com/repos/carlrobert/double-switch/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/carlrobert/double-switch/events',
#       'assignees_url': 'https://api.github.com/repos/carlrobert/double-switch/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/carlrobert/double-switch/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/carlrobert/double-switch/tags',
#       'blobs_url': 'https://api.github.com/repos/carlrobert/double-switch/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/carlrobert/double-switch/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/carlrobert/double-switch/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/carlrobert/double-switch/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/carlrobert/double-switch/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/carlrobert/double-switch/languages',
#       'stargazers_url': 'https://api.github.com/repos/carlrobert/double-switch/stargazers',
#       'contributors_url': 'https://api.github.com/repos/carlrobert/double-switch/contributors',
#       'subscribers_url': 'https://api.github.com/repos/carlrobert/double-switch/subscribers',
#       'subscription_url': 'https://api.github.com/repos/carlrobert/double-switch/subscription',
#       'commits_url': 'https://api.github.com/repos/carlrobert/double-switch/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/carlrobert/double-switch/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/carlrobert/double-switch/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/carlrobert/double-switch/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/carlrobert/double-switch/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/carlrobert/double-switch/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/carlrobert/double-switch/merges',
#       'archive_url': 'https://api.github.com/repos/carlrobert/double-switch/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/carlrobert/double-switch/downloads',
#       'issues_url': 'https://api.github.com/repos/carlrobert/double-switch/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/carlrobert/double-switch/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/carlrobert/double-switch/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/carlrobert/double-switch/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/carlrobert/double-switch/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/carlrobert/double-switch/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/carlrobert/double-switch/deployments',
#       'created_at': '2024-11-10T16:45:22Z',
#       'updated_at': '2024-11-15T20:36:49Z',
#       'pushed_at': '2024-11-15T21:05:06Z',
#       'git_url': 'git://github.com/carlrobert/double-switch.git',
#       'ssh_url': 'git@github.com:carlrobert/double-switch.git',
#       'clone_url': 'https://github.com/carlrobert/double-switch.git',
#       'svn_url': 'https://github.com/carlrobert/double-switch',
#       'homepage': None,
#       'size': 74,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'TypeScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/carlrobert/double-switch/pulls/2'},
#      'html': {'href': 'https://github.com/carlrobert/double-switch/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/carlrobert/double-switch/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/carlrobert/double-switch/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/carlrobert/double-switch/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/carlrobert/double-switch/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/carlrobert/double-switch/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/carlrobert/double-switch/statuses/c850bb868e0159dbed7f97218d2b19db3dad8616'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 4,
#     'additions': 36,
#     'deletions': 14,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393995',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 291463592,
#    'name': 'hrichiksite/hrichiksite',
#    'url': 'https://api.github.com/repos/hrichiksite/hrichiksite'},
#   'payload': {'repository_id': 291463592,
#    'push_id': 21240490319,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c5116f45700663249df6b3c4b85c1574c6164418',
#    'before': '01d125d8f9c7eae79e4df9c7e525b7dc266bdbe2',
#    'commits': [{'sha': 'c5116f45700663249df6b3c4b85c1574c6164418',
#      'author': {'email': '41898282+github-actions[bot]@users.noreply.github.com',
#       'name': 'github-actions[bot]'},
#      'message': 'Update github-metrics.svg - [Skip GitHub Action]',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/hrichiksite/hrichiksite/commits/c5116f45700663249df6b3c4b85c1574c6164418'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393984',
#   'type': 'PushEvent',
#   'actor': {'id': 115139640,
#    'login': 'freecall2019',
#    'display_login': 'freecall2019',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/freecall2019',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115139640?'},
#   'repo': {'id': 881419220,
#    'name': 'freecall2019/day',
#    'url': 'https://api.github.com/repos/freecall2019/day'},
#   'payload': {'repository_id': 881419220,
#    'push_id': 21240490296,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '51b1018e89a04a18aee90f8f59c2473d083e14f6',
#    'before': 'eff6fc04b59a021b4ffc29722c8c8ea183cbde8f',
#    'commits': [{'sha': '51b1018e89a04a18aee90f8f59c2473d083e14f6',
#      'author': {'email': '115139640+freecall2019@users.noreply.github.com',
#       'name': 'freecall'},
#      'message': 'super',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/freecall2019/day/commits/51b1018e89a04a18aee90f8f59c2473d083e14f6'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393988',
#   'type': 'CreateEvent',
#   'actor': {'id': 22028333,
#    'login': 'hacc1225',
#    'display_login': 'hacc1225',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hacc1225',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22028333?'},
#   'repo': {'id': 889218685,
#    'name': 'hacc1225/element-web',
#    'url': 'https://api.github.com/repos/hacc1225/element-web'},
#   'payload': {'ref': 'release',
#    'ref_type': 'branch',
#    'master_branch': 'develop',
#    'description': 'A glossy Matrix collaboration client for the web.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393970',
#   'type': 'PushEvent',
#   'actor': {'id': 3895924,
#    'login': 'qhduan',
#    'display_login': 'qhduan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qhduan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3895924?'},
#   'repo': {'id': 613422249,
#    'name': 'qhduan/cn-chat-arxiv',
#    'url': 'https://api.github.com/repos/qhduan/cn-chat-arxiv'},
#   'payload': {'repository_id': 613422249,
#    'push_id': 21240490272,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e2472b30806b838b23619444d7ee81c6e2edea52',
#    'before': 'e00b7b74c4b3b869073f75571e9ba88ae3c185b9',
#    'commits': [{'sha': 'e2472b30806b838b23619444d7ee81c6e2edea52',
#      'author': {'email': 'mail@qhduan.com', 'name': 'qhduan'},
#      'message': 'Add changes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/qhduan/cn-chat-arxiv/commits/e2472b30806b838b23619444d7ee81c6e2edea52'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393972',
#   'type': 'PushEvent',
#   'actor': {'id': 6529957,
#    'login': 'reinamora137',
#    'display_login': 'reinamora137',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/reinamora137',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6529957?'},
#   'repo': {'id': 708156888,
#    'name': 'stampchain-io/btc_stamps',
#    'url': 'https://api.github.com/repos/stampchain-io/btc_stamps'},
#   'payload': {'repository_id': 708156888,
#    'push_id': 21240490299,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/bitname/latest',
#    'head': '6b71970acb9c780445eb7cabc00aee737db5396f',
#    'before': 'f11d07bcb85b230fba2538f6b89884e2b159bb00',
#    'commits': [{'sha': '6b71970acb9c780445eb7cabc00aee737db5396f',
#      'author': {'email': '82604458@qq.com', 'name': 'yinwei'},
#      'message': 'Move the calculation of block timestamp to src101',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/stampchain-io/btc_stamps/commits/6b71970acb9c780445eb7cabc00aee737db5396f'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 134318848,
#    'login': 'stampchain-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/stampchain-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/134318848?'}},
#  {'id': '43878393985',
#   'type': 'DeleteEvent',
#   'actor': {'id': 161623942,
#    'login': 'sidz22',
#    'display_login': 'sidz22',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sidz22',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/161623942?'},
#   'repo': {'id': 889091045,
#    'name': 'sidz22/Angular_Projects-Assignments',
#    'url': 'https://api.github.com/repos/sidz22/Angular_Projects-Assignments'},
#   'payload': {'ref': 'main', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393955',
#   'type': 'PushEvent',
#   'actor': {'id': 131243847,
#    'login': 'devpoole2907',
#    'display_login': 'devpoole2907',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/devpoole2907',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/131243847?'},
#   'repo': {'id': 773190049,
#    'name': 'devpoole2907/helldivers-api-cache',
#    'url': 'https://api.github.com/repos/devpoole2907/helldivers-api-cache'},
#   'payload': {'repository_id': 773190049,
#    'push_id': 21240490302,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f365d3cf4bdd826f10715dfdb40745935ee6c56f',
#    'before': 'e5a65ae8f375a54f4bc40dcf5d1358d87dbfb3c9',
#    'commits': [{'sha': 'f365d3cf4bdd826f10715dfdb40745935ee6c56f',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Actions Bot'},
#      'message': 'Update current planet data',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/devpoole2907/helldivers-api-cache/commits/f365d3cf4bdd826f10715dfdb40745935ee6c56f'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393953',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 129717717,
#    'name': 'grafana/loki',
#    'url': 'https://api.github.com/repos/grafana/loki'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/grafana/loki/issues/14954',
#     'repository_url': 'https://api.github.com/repos/grafana/loki',
#     'labels_url': 'https://api.github.com/repos/grafana/loki/issues/14954/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/grafana/loki/issues/14954/comments',
#     'events_url': 'https://api.github.com/repos/grafana/loki/issues/14954/events',
#     'html_url': 'https://github.com/grafana/loki/pull/14954',
#     'id': 2662696220,
#     'node_id': 'PR_kwDOB7tV1c6CE0Ws',
#     'number': 14954,
#     'title': 'chore(deps): update helm release grafana-agent-operator to v0.5.0',
#     'user': {'login': 'renovate[bot]',
#      'id': 29139614,
#      'node_id': 'MDM6Qm90MjkxMzk2MTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/2740?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/renovate%5Bbot%5D',
#      'html_url': 'https://github.com/apps/renovate',
#      'followers_url': 'https://api.github.com/users/renovate%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/renovate%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/renovate%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/renovate%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/renovate%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'labels': [{'id': 1785651610,
#       'node_id': 'MDU6TGFiZWwxNzg1NjUxNjEw',
#       'url': 'https://api.github.com/repos/grafana/loki/labels/size/S',
#       'name': 'size/S',
#       'color': '5D9801',
#       'default': False,
#       'description': None},
#      {'id': 3718702345,
#       'node_id': 'LA_kwDOB7tV1c7dpuUJ',
#       'url': 'https://api.github.com/repos/grafana/loki/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'},
#      {'id': 4227262886,
#       'node_id': 'LA_kwDOB7tV1c779umm',
#       'url': 'https://api.github.com/repos/grafana/loki/labels/area/helm',
#       'name': 'area/helm',
#       'color': '8E7723',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2024-11-15T17:39:09Z',
#     'updated_at': '2024-11-15T21:05:38Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'sub_issues_summary': {'total': 0, 'completed': 0, 'percent_completed': 0},
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/grafana/loki/pulls/14954',
#      'html_url': 'https://github.com/grafana/loki/pull/14954',
#      'diff_url': 'https://github.com/grafana/loki/pull/14954.diff',
#      'patch_url': 'https://github.com/grafana/loki/pull/14954.patch',
#      'merged_at': None},
#     'body': "This PR contains the following updates:\n\n| Package | Update | Change |\n|---|---|---|\n| [grafana-agent-operator](https://grafana.com/docs/agent/v0.43/) ([source](https://redirect.github.com/grafana/helm-charts)) | minor | `0.3.15` -> `0.5.0` |\n\n---\n\n### Release Notes\n\n<details>\n<summary>grafana/helm-charts (grafana-agent-operator)</summary>\n\n### [`v0.5.0`](https://redirect.github.com/grafana/helm-charts/releases/tag/grafana-agent-operator-0.5.0)\n\n[Compare Source](https://redirect.github.com/grafana/helm-charts/compare/grafana-agent-operator-0.4.4...grafana-agent-operator-0.5.0)\n\nA Helm chart for Grafana Agent Operator\n\n#### What's Changed\n\n-   \\[agent-operator] Add commonLabels ([#&#8203;3319](https://redirect.github.com/grafana/helm-charts/issues/3319)) by [@&#8203;ramon951](https://redirect.github.com/ramon951) in [https://github.com/grafana/helm-charts/pull/3385](https://redirect.github.com/grafana/helm-charts/pull/3385)\n\n**Full Changelog**: https://github.com/grafana/helm-charts/compare/tempo-distributed-1.20.1...grafana-agent-operator-0.5.0\n\n### [`v0.4.4`](https://redirect.github.com/grafana/helm-charts/releases/tag/grafana-agent-operator-0.4.4)\n\n[Compare Source](https://redirect.github.com/grafana/helm-charts/compare/grafana-agent-operator-0.4.3...grafana-agent-operator-0.4.4)\n\nA Helm chart for Grafana Agent Operator\n\n#### What's Changed\n\n-   \\[agent-operator] bump agent version v0.43.3 by [@&#8203;wildum](https://redirect.github.com/wildum) in [https://github.com/grafana/helm-charts/pull/3331](https://redirect.github.com/grafana/helm-charts/pull/3331)\n\n**Full Changelog**: https://github.com/grafana/helm-charts/compare/alloy-0.8.0...grafana-agent-operator-0.4.4\n\n### [`v0.4.3`](https://redirect.github.com/grafana/helm-charts/releases/tag/grafana-agent-operator-0.4.3)\n\n[Compare Source](https://redirect.github.com/grafana/helm-charts/compare/grafana-agent-operator-0.4.2...grafana-agent-operator-0.4.3)\n\nA Helm chart for Grafana Agent Operator\n\n#### What's Changed\n\n-   \\[agent-operator] update agent to v0.43.2 by [@&#8203;wildum](https://redirect.github.com/wildum) in [https://github.com/grafana/helm-charts/pull/3328](https://redirect.github.com/grafana/helm-charts/pull/3328)\n\n#### New Contributors\n\n-   [@&#8203;wildum](https://redirect.github.com/wildum) made their first contribution in [https://github.com/grafana/helm-charts/pull/3328](https://redirect.github.com/grafana/helm-charts/pull/3328)\n\n**Full Changelog**: https://github.com/grafana/helm-charts/compare/grafana-sampling-1.1.0...grafana-agent-operator-0.4.3\n\n### [`v0.4.2`](https://redirect.github.com/grafana/helm-charts/releases/tag/grafana-agent-operator-0.4.2)\n\n[Compare Source](https://redirect.github.com/grafana/helm-charts/compare/grafana-agent-operator-0.4.1...grafana-agent-operator-0.4.2)\n\nA Helm chart for Grafana Agent Operator\n\n#### What's Changed\n\n-   \\[agent-operator] Update for Agent 0.43.0 by [@&#8203;ptodev](https://redirect.github.com/ptodev) in [https://github.com/grafana/helm-charts/pull/3306](https://redirect.github.com/grafana/helm-charts/pull/3306)\n\n**Full Changelog**: https://github.com/grafana/helm-charts/compare/beyla-1.4.0...grafana-agent-operator-0.4.2\n\n### [`v0.4.1`](https://redirect.github.com/grafana/helm-charts/releases/tag/grafana-agent-operator-0.4.1)\n\n[Compare Source](https://redirect.github.com/grafana/helm-charts/compare/grafana-agent-operator-0.4.0...grafana-agent-operator-0.4.1)\n\nA Helm chart for Grafana Agent Operator\n\n#### What's Changed\n\n-   \\[agent-operator] Update chart to Agent 0.42.0 by [@&#8203;ptodev](https://redirect.github.com/ptodev) in [https://github.com/grafana/helm-charts/pull/3239](https://redirect.github.com/grafana/helm-charts/pull/3239)\n\n**Full Changelog**: https://github.com/grafana/helm-charts/compare/grafana-agent-0.42.0...grafana-agent-operator-0.4.1\n\n### [`v0.4.0`](https://redirect.github.com/grafana/helm-charts/rele ...
#     'reactions': {'url': 'https://api.github.com/repos/grafana/loki/issues/14954/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/grafana/loki/issues/14954/timeline',
#     'performed_via_github_app': None,
#     'state_reason': None},
#    'comment': {'url': 'https://api.github.com/repos/grafana/loki/issues/comments/2479922206',
#     'html_url': 'https://github.com/grafana/loki/pull/14954#issuecomment-2479922206',
#     'issue_url': 'https://api.github.com/repos/grafana/loki/issues/14954',
#     'id': 2479922206,
#     'node_id': 'IC_kwDOB7tV1c6T0Jwe',
#     'user': {'login': 'renovate[bot]',
#      'id': 29139614,
#      'node_id': 'MDM6Qm90MjkxMzk2MTQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/2740?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/renovate%5Bbot%5D',
#      'html_url': 'https://github.com/apps/renovate',
#      'followers_url': 'https://api.github.com/users/renovate%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/renovate%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/renovate%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/renovate%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/renovate%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/renovate%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/renovate%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/renovate%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/renovate%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'created_at': '2024-11-15T21:05:36Z',
#     'updated_at': '2024-11-15T21:05:36Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '### Edited/Blocked Notification\n\nRenovate will not automatically rebase this PR, because it does not recognize the last commit author and assumes somebody else may have edited the PR.\n\nYou can manually request rebase by checking the rebase/retry box above.\n\n ⚠️ **Warning**: custom changes will be lost.',
#     'reactions': {'url': 'https://api.github.com/repos/grafana/loki/issues/comments/2479922206/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': {'id': 2740,
#      'client_id': 'Iv1.9f820358a2aa6747',
#      'slug': 'renovate',
#      'node_id': 'MDM6QXBwMjc0MA==',
#      'owner': {'login': 'renovatebot',
#       'id': 38656520,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjM4NjU2NTIw',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/38656520?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/renovatebot',
#       'html_url': 'https://github.com/renovatebot',
#       'followers_url': 'https://api.github.com/users/renovatebot/followers',
#       'following_url': 'https://api.github.com/users/renovatebot/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/renovatebot/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/renovatebot/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/renovatebot/subscriptions',
#       'organizations_url': 'https://api.github.com/users/renovatebot/orgs',
#       'repos_url': 'https://api.github.com/users/renovatebot/repos',
#       'events_url': 'https://api.github.com/users/renovatebot/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/renovatebot/received_events',
#       'type': 'Organization',
#       'user_view_type': 'public',
#       'site_admin': False},
#      'name': 'Renovate',
#      'description': '## Automated Dependency Updates\r\n\r\n[Mend Renovate](https://www.mend.io/renovate/) keeps source code dependencies up-to-date using automated Pull Requests. It will scan repositories for package manager files (e.g. from npm/Yarn, Bundler, Composer, Go Modules, Pip/Pipenv/Poetry, Maven/Gradle, Dockerfile/k8s, and many more), and submit Pull Requests with updated versions whenever they are found.\r\n\r\nThis app is free to install for both public and private repositories. Service is provided complimentary of Mend (formerly known as WhiteSource) and no paid plan is required.\r\n\r\n### Intelligent, helpful onboarding\r\n\r\n![Onboarding](https://docs.renovatebot.com/assets/images/onboarding.png)\r\n\r\nInstall Mend Renovate risk-free and you\'ll first receive an onboarding Pull Request in each repository. It analyzes the repository files and describes what will happen next, so there\'s no surprises. \r\n\r\n### Unopinionated, highly flexible configuration\r\n\r\n```json\r\n{\r\n  "rangeStrategy": "pin",\r\n  "ignorePaths": ["examples/**"],\r\n  "packageRules": [{\r\n    "packagePatterns": ["^angular.*"],\r\n    "groupName": "angular",\r\n    "automerge": true\r\n  }]\r\n}\r\n```\r\n\r\nModify any of Renovate\'s smart defaults with custom overrides at the repository, package file, dependency type, and package levels. \r\n\r\n### Support for monorepo directory structures\r\n\r\nRenovate will scan all files in each repository to look for relevant package files. It will also group upgrades from the same monorepo into a single PR to ensure tests pass and PR noise is reduced. Natively supports Lerna and Yarn Workspaces with zero configuration necessary.\r\n\r\nIt is also works fine with a mix of package managers / languages within the same repository.\r\n\r\n### Automatic lock file and checksum support\r\n\r\nRenovate will generate updated lock files such as `package-lock.json` or `yarn.lock` if you\'re already using them. It will also automatically resolve any conflicts after merges.\r\n\r\n### Ease the noise with custom schedules\r\n\r\n```json\r\n{\r\n  "timezone": "America/New_York",\r\n  "schedule": "before 5am every weekday",\r\n  "lockFileMaintenance": {\r\n    "enabled": true,\r\n    "schedule": "after 10pm on sunday"\r\n  },\r\n  "packageRules": [{\r\n    "packageNames": ["aws-sdk"],\r\n    "schedule": "before 5am every wednesday"\r\n  }]\r\n}\r\n```\r\n\r\nThrottle updates however you want with schedules, configurable right down to the per-package level.\r\n\r\n### Rules-based automerging\r\n\r\n![automerging](https://docs.renovatebot.com/assets/images/automerged-pr.png)\r\n\r\nMerge some updates without human intervention if they pass tests and satisfy your automerge rules.',
#      'external_url': 'https://www.mend.io/renovate/',
#      'html_url': 'https://github.com/apps/renovate',
#      'created_at': '2017-06-02T07:04:12Z',
#      'updated_at': '2024-10-28T08:56:39Z',
#      'permissions': {'administration': 'read',
#       'checks': 'write',
#       'contents': 'write',
#       'emails': 'read',
#       'issues': 'write',
#       'members': 'read',
#       'metadata': 'read',
#       'packages': 'read',
#       'pull_requests': 'write',
#       'statuses': 'write',
#       'vulnerability_alerts': 'read',
#       'workflows': 'write'},
#      'events': ['issues', 'pull_request', 'push', 'repository']}}},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 7195757,
#    'login': 'grafana',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/grafana',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7195757?'}},
#  {'id': '43878393961',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 538862510,
#    'name': 'peesaeung/vendingmachine',
#    'url': 'https://api.github.com/repos/peesaeung/vendingmachine'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/eslint/plugin-kit-0.2.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Vending Machine Simulator',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393933',
#   'type': 'PushEvent',
#   'actor': {'id': 99732548,
#    'login': 'Alexey-Gorulev-kernelics',
#    'display_login': 'Alexey-Gorulev-kernelics',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alexey-Gorulev-kernelics',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/99732548?'},
#   'repo': {'id': 594025893,
#    'name': 'magicwave-io/go-libp2p-kad-dht',
#    'url': 'https://api.github.com/repos/magicwave-io/go-libp2p-kad-dht'},
#   'payload': {'repository_id': 594025893,
#    'push_id': 21240490256,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/fix/loggable-key',
#    'head': '43dd084364c264316a32abefcbf261b0b8e30ce6',
#    'before': '21b6e951b3767eb69a4e413399b9032b44c8cf76',
#    'commits': [{'sha': '43dd084364c264316a32abefcbf261b0b8e30ce6',
#      'author': {'email': 'a.gorulev@kernelics.com', 'name': 'a.gorulev'},
#      'message': 'magicwave.io',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/magicwave-io/go-libp2p-kad-dht/commits/43dd084364c264316a32abefcbf261b0b8e30ce6'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 123494304,
#    'login': 'magicwave-io',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/magicwave-io',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/123494304?'}},
#  {'id': '43878393938',
#   'type': 'CreateEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 792403915,
#    'name': 'abinnovision/github-workflow-dispatch-proxy',
#    'url': 'https://api.github.com/repos/abinnovision/github-workflow-dispatch-proxy'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/eslint/plugin-kit-0.2.3',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': "💥 Authenticated proxy for GitHub Actions' workflow_dispatch event",
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 115591608,
#    'login': 'abinnovision',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/abinnovision',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/115591608?'}},
#  {'id': '43878393920',
#   'type': 'CreateEvent',
#   'actor': {'id': 135270994,
#    'login': 'Ian-Nara',
#    'display_login': 'Ian-Nara',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ian-Nara',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/135270994?'},
#   'repo': {'id': 390578545,
#    'name': 'IABTechLab/uid2-client-python',
#    'url': 'https://api.github.com/repos/IABTechLab/uid2-client-python'},
#   'payload': {'ref': 'ian-update-action-versions',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 82903538,
#    'login': 'IABTechLab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/IABTechLab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/82903538?'}},
#  {'id': '43878393924',
#   'type': 'CreateEvent',
#   'actor': {'id': 70470993,
#    'login': 'agav99',
#    'display_login': 'agav99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/agav99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70470993?'},
#   'repo': {'id': 344196584,
#    'name': 'agav99/ioBroker.zigbee',
#    'url': 'https://api.github.com/repos/agav99/ioBroker.zigbee'},
#   'payload': {'ref': 'branch_common',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Zigbee communcation with Hue, Xiaomi, Lighttify... via TI CC253x USB stick',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393901',
#   'type': 'PushEvent',
#   'actor': {'id': 3315682,
#    'login': 'shamangeorge',
#    'display_login': 'shamangeorge',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shamangeorge',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3315682?'},
#   'repo': {'id': 341941502,
#    'name': 'shamangeorge/dotfiles',
#    'url': 'https://api.github.com/repos/shamangeorge/dotfiles'},
#   'payload': {'repository_id': 341941502,
#    'push_id': 21240490248,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': 'b61ad3828af02792b379a434ca71364bf9472ed6',
#    'before': '185fbc6f0cab495f075c063c3385e04824bf65d7',
#    'commits': [{'sha': '39d7efdfe169cd94955c635646eaf10a85ddc4a2',
#      'author': {'email': 'george@avlos.ai', 'name': 'shamangeorge'},
#      'message': 'plugins: add noice, snacks and neoconf and update coc settings and\nextensions.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shamangeorge/dotfiles/commits/39d7efdfe169cd94955c635646eaf10a85ddc4a2'},
#     {'sha': 'b61ad3828af02792b379a434ca71364bf9472ed6',
#      'author': {'email': 'your_email', 'name': 'your_name'},
#      'message': "Merge branch 'neovim-config'\n\n* neovim-config:\n  plugins: add noice, snacks and neoconf and update coc settings and extensions.",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/shamangeorge/dotfiles/commits/b61ad3828af02792b379a434ca71364bf9472ed6'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393889',
#   'type': 'PushEvent',
#   'actor': {'id': 155732037,
#    'login': 'OuachouX7',
#    'display_login': 'OuachouX7',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/OuachouX7',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/155732037?'},
#   'repo': {'id': 885601135,
#    'name': 'OuachouX7/weather-app-v2',
#    'url': 'https://api.github.com/repos/OuachouX7/weather-app-v2'},
#   'payload': {'repository_id': 885601135,
#    'push_id': 21240490253,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/tkhrbi9a',
#    'head': 'ef0bcfd56639d87129d732b5a7ee61d85614fd83',
#    'before': 'bf2d666c0f68aa04df85a4d5058551c8725cc85f',
#    'commits': [{'sha': 'ef0bcfd56639d87129d732b5a7ee61d85614fd83',
#      'author': {'email': 'ouachou9@gmail.com', 'name': 'OuachouX7'},
#      'message': 'droppp',
#      'distinct': True,
# ...
#       'updated_at': '2024-11-12T13:20:15Z',
#       'pushed_at': '2024-11-13T15:48:22Z',
#       'git_url': 'git://github.com/Mateoo18/FuelMate.git',
#       'ssh_url': 'git@github.com:Mateoo18/FuelMate.git',
#       'clone_url': 'https://github.com/Mateoo18/FuelMate.git',
#       'svn_url': 'https://github.com/Mateoo18/FuelMate',
#       'homepage': None,
#       'size': 10949,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'has_discussions': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'allow_forking': True,
#       'is_template': False,
#       'web_commit_signoff_required': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/pulls/3'},
#      'html': {'href': 'https://github.com/Mateoo18/FuelMate/pull/3'},
#      'issue': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/issues/3'},
#      'comments': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/issues/3/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/pulls/3/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/pulls/3/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Mateoo18/FuelMate/statuses/86501690a8b13ebf4711e646dda4b7d59ac78518'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'Mateoo18',
#      'id': 73141657,
#      'node_id': 'MDQ6VXNlcjczMTQxNjU3',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/73141657?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Mateoo18',
#      'html_url': 'https://github.com/Mateoo18',
#      'followers_url': 'https://api.github.com/users/Mateoo18/followers',
#      'following_url': 'https://api.github.com/users/Mateoo18/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Mateoo18/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Mateoo18/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Mateoo18/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Mateoo18/orgs',
#      'repos_url': 'https://api.github.com/users/Mateoo18/repos',
#      'events_url': 'https://api.github.com/users/Mateoo18/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Mateoo18/received_events',
#      'type': 'User',
#      'user_view_type': 'public',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 1028,
#     'deletions': 14,
#     'changed_files': 32}},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393838',
#   'type': 'PushEvent',
#   'actor': {'id': 163454341,
#    'login': 'PessimistA',
#    'display_login': 'PessimistA',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PessimistA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/163454341?'},
#   'repo': {'id': 865500334,
#    'name': 'PessimistA/data_structures',
#    'url': 'https://api.github.com/repos/PessimistA/data_structures'},
#   'payload': {'repository_id': 865500334,
#    'push_id': 21240490230,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '250f711d0b72e45bc6a654532d82a3a2f9c9ca84',
#    'before': 'b51e58172620cd72df39742c2823fab5c866ad88',
#    'commits': [{'sha': '250f711d0b72e45bc6a654532d82a3a2f9c9ca84',
#      'author': {'email': '163454341+PessimistA@users.noreply.github.com',
#       'name': 'EcenurSarıkaya'},
#      'message': 'Update infix_calculate.cpp',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/PessimistA/data_structures/commits/250f711d0b72e45bc6a654532d82a3a2f9c9ca84'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393831',
#   'type': 'PushEvent',
#   'actor': {'id': 88674951,
#    'login': 'jacob-pegues',
#    'display_login': 'jacob-pegues',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jacob-pegues',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/88674951?'},
#   'repo': {'id': 889084219,
#    'name': 'jacob-pegues/ece281-book',
#    'url': 'https://api.github.com/repos/jacob-pegues/ece281-book'},
#   'payload': {'repository_id': 889084219,
#    'push_id': 21240490263,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '656d515d170a8ca4107247981a6289620a1dfa37',
#    'before': 'de9ef965d39696c024a549292ac55a9c140fccb0',
#    'commits': [{'sha': '656d515d170a8ca4107247981a6289620a1dfa37',
#      'author': {'email': '88674951+jacob-pegues@users.noreply.github.com',
#       'name': 'jacob-pegues'},
#      'message': 'Fixed a lot of stuff',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jacob-pegues/ece281-book/commits/656d515d170a8ca4107247981a6289620a1dfa37'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393818',
#   'type': 'PushEvent',
#   'actor': {'id': 17087985,
#    'login': 'ericmwalk',
#    'display_login': 'ericmwalk',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ericmwalk',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17087985?'},
#   'repo': {'id': 437452206,
#    'name': 'ericmwalk/mb.backup',
#    'url': 'https://api.github.com/repos/ericmwalk/mb.backup'},
#   'payload': {'repository_id': 437452206,
#    'push_id': 21240490240,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'aec4098f36c676ea266af6b4247c7e053ef8363f',
#    'before': 'adc71991fc7ec9b18431e63887d8c81bdf33f49a',
#    'commits': [{'sha': 'aec4098f36c676ea266af6b4247c7e053ef8363f',
#      'author': {'email': 'eric@brebs.net', 'name': 'ericmwalk'},
#      'message': 'Archiving from Micro.blog.',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ericmwalk/mb.backup/commits/aec4098f36c676ea266af6b4247c7e053ef8363f'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:37Z'},
#  {'id': '43878393841',
#   'type': 'PushEvent',
#   'actor': {'id': 1132745,
#    'login': 'TilmanGriesel',
#    'display_login': 'TilmanGriesel',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/TilmanGriesel',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1132745?'},
#   'repo': {'id': 574163721,
#    'name': 'TilmanGriesel/graphite',
#    'url': 'https://api.github.com/repos/TilmanGriesel/graphite'},
#   'payload': {'repository_id': 574163721,
#    'push_id': 21240490259,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/35-add-sections-styling-and-small-visual-improvements',
#    'head': '7959b5e6841184b115844d88e95d61ae2ca216df',
#    'before': '079957ce5ab0a7757d26f0143b6a93b4088c4c60',
#    'commits': [{'sha': '7959b5e6841184b115844d88e95d61ae2ca216df',
#      'author': {'email': 'griesel@me.com', 'name': 'Tilman Griesel'},
#      'message': '[DROP] validation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/TilmanGriesel/graphite/commits/7959b5e6841184b115844d88e95d61ae2ca216df'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z'},
#  {'id': '43878393815',
#   'type': 'PushEvent',
#   'actor': {'id': 121419152,
#    'login': 'daeguhighman',
#    'display_login': 'daeguhighman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/daeguhighman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/121419152?'},
#   'repo': {'id': 888581812,
#    'name': 'daeguhighman/dading-coding-ps',
#    'url': 'https://api.github.com/repos/daeguhighman/dading-coding-ps'},
#   'payload': {'repository_id': 888581812,
#    'push_id': 21240490231,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '7483f40e4352a9fad1e04cf32a64d909ac002bf9',
#    'before': '1c4432f67e59284833cac3c29c912eff649a891e',
#    'commits': [{'sha': '7483f40e4352a9fad1e04cf32a64d909ac002bf9',
#      'author': {'email': 'action@github.com', 'name': 'GitHub Action'},
#      'message': 'update: progress tracking',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/daeguhighman/dading-coding-ps/commits/7483f40e4352a9fad1e04cf32a64d909ac002bf9'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:37Z'},
#  {'id': '43878393846',
#   'type': 'WatchEvent',
#   'actor': {'id': 4264513,
#    'login': 'ninanoe',
#    'display_login': 'ninanoe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ninanoe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4264513?'},
#   'repo': {'id': 1864194,
#    'name': 'frappe/frappe',
#    'url': 'https://api.github.com/repos/frappe/frappe'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 836974,
#    'login': 'frappe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/frappe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/836974?'}},
#  {'id': '43878393828',
#   'type': 'CreateEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 428859629,
#    'name': 'Crossmint/crossmint-sdk',
#    'url': 'https://api.github.com/repos/Crossmint/crossmint-sdk'},
#   'payload': {'ref': 'changeset-release/main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Crossmint SDK for client and server integrations',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:38Z',
#   'org': {'id': 95070156,
#    'login': 'Crossmint',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Crossmint',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/95070156?'}},
#  {'id': '43878393814',
#   'type': 'DeleteEvent',
#   'actor': {'id': 8608880,
#    'login': 'Zer0dot',
#    'display_login': 'Zer0dot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Zer0dot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8608880?'},
#   'repo': {'id': 720239677,
#    'name': 'alchemyplatform/modular-account',
#    'url': 'https://api.github.com/repos/alchemyplatform/modular-account'},
#   'payload': {'ref': 'zer0dot/fix-qs-01',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:37Z',
#   'org': {'id': 49798644,
#    'login': 'alchemyplatform',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/alchemyplatform',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49798644?'}},
#  {'id': '43878393806',
#   'type': 'WatchEvent',
#   'actor': {'id': 71158634,
#    'login': 'bklatham',
#    'display_login': 'bklatham',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bklatham',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71158634?'},
#   'repo': {'id': 64705781,
#    'name': 'SwifterSwift/SwifterSwift',
#    'url': 'https://api.github.com/repos/SwifterSwift/SwifterSwift'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2024-11-15T21:05:37Z',
#   'org': {'id': 25029478,
#    'login': 'SwifterSwift',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/SwifterSwift',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25029478?'}},
#  {'id': '43878393780',
#   'type': 'PushEvent',
#   'actor': {'id': 171149451,
#    'login': 'XvSvM',
#    'display_login': 'XvSvM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/XvSvM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/171149451?'},
#   'repo': {'id': 862272854,
#    'name': 'XvSvM/H728PROPLUS',
#    'url': 'https://api.github.com/repos/XvSvM/H728PROPLUS'},
#   'payload': {'repository_id': 862272854,
#    'push_id': 21240490192,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/diana_p1_arm64-userdebug-14-UP1A.231105.001.A1-eng.ubuntu.20240807.160822-release-keys',
#    'head': '1f07c4be552e3866ccc1b209a9266f9e394166df',
#    'before': '02ebbe6876370273866f84323c808d2fde7836ab',
#    'commits': [{'sha': '1f07c4be552e3866ccc1b209a9266f9e394166df',
#      'author': {'email': 'vadiagadia@gmail.com', 'name': 'XvSvM'},
#      'message': 'Delete extract-files.sh',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/XvSvM/H728PROPLUS/commits/1f07c4be552e3866ccc1b209a9266f9e394166df'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:37Z'},
#  {'id': '43878393751',
#   'type': 'PushEvent',
#   'actor': {'id': 9913164,
#    'login': 'durandtibo',
#    'display_login': 'durandtibo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/durandtibo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9913164?'},
#   'repo': {'id': 582456937,
#    'name': 'durandtibo/coola',
#    'url': 'https://api.github.com/repos/durandtibo/coola'},
#   'payload': {'repository_id': 582456937,
#    'push_id': 21240490223,
#    'size': 3,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dependabot/pip/mkdocs-material-9.5.44',
#    'head': 'c6edf6888359b765512629d3f01c8fcbbfbee35a',
#    'before': 'a3d641a5afa084376bd35fe91cc389a8dd252b3f',
#    'commits': [{'sha': 'e114ee57bffb548a2532d2f83c7c94ffb38f9892',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump durandtibo/pip-install-package-action from 0.3.0 to 0.3.1 (#768)\n\nBumps [durandtibo/pip-install-package-action](https://github.com/durandtibo/pip-install-package-action) from 0.3.0 to 0.3.1.\r\n- [Release notes](https://github.com/durandtibo/pip-install-package-action/releases)\r\n- [Commits](https://github.com/durandtibo/pip-install-package-action/compare/v0.3.0...v0.3.1)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: durandtibo/pip-install-package-action\r\n  dependency-type: direct:production\r\n  update-type: version-update:semver-patch\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/durandtibo/coola/commits/e114ee57bffb548a2532d2f83c7c94ffb38f9892'},
#     {'sha': '0e9a519fd154790a04bf572a08089e151934a68f',
#      'author': {'email': '49699333+dependabot[bot]@users.noreply.github.com',
#       'name': 'dependabot[bot]'},
#      'message': 'Bump mkdocstrings from 0.26.2 to 0.27.0 (#767)\n\nBumps [mkdocstrings](https://github.com/mkdocstrings/mkdocstrings) from 0.26.2 to 0.27.0.\r\n- [Release notes](https://github.com/mkdocstrings/mkdocstrings/releases)\r\n- [Changelog](https://github.com/mkdocstrings/mkdocstrings/blob/main/CHANGELOG.md)\r\n- [Commits](https://github.com/mkdocstrings/mkdocstrings/compare/0.26.2...0.27.0)\r\n\r\n---\r\nupdated-dependencies:\r\n- dependency-name: mkdocstrings\r\n  dependency-type: direct:development\r\n  update-type: version-update:semver-minor\r\n...\r\n\r\nSigned-off-by: dependabot[bot] <support@github.com>\r\nCo-authored-by: dependabot[bot] <49699333+dependabot[bot]@users.noreply.github.com>\r\nCo-authored-by: Thibaut Durand <durand.tibo@gmail.com>',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/durandtibo/coola/commits/0e9a519fd154790a04bf572a08089e151934a68f'},
#     {'sha': 'c6edf6888359b765512629d3f01c8fcbbfbee35a',
#      'author': {'email': 'durand.tibo@gmail.com', 'name': 'Thibaut Durand'},
#      'message': "Merge branch 'main' into dependabot/pip/mkdocs-material-9.5.44",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/durandtibo/coola/commits/c6edf6888359b765512629d3f01c8fcbbfbee35a'}]},
#   'public': True,
#   'created_at': '2024-11-15T21:05:37Z'}]

# %% [markdown]
# Utilizando outro endpoint

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']

# %% [markdown]
# ## Extraindo dados

# %% [markdown]
# ### Obtendo dados dos repositórios

# %%
# especificando a versão da API
headers = {'X-GitHub-Api-Version': '2022-11-28'}

# %%
api_base_url = 'https://api.github.com'
onwer = 'amzn'
url = f'{api_base_url}/users/{onwer}/repos'

# %%
url
# Out:
# 'https://api.github.com/users/amzn/repos'

# %%
response =  requests.get(url,headers=headers)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# [{'id': 171339259,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkxNzEzMzkyNTk=',
#   'name': '.github',
#   'full_name': 'amzn/.github',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/.github',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/.github',
#   'forks_url': 'https://api.github.com/repos/amzn/.github/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/.github/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/.github/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/.github/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/.github/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/.github/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/.github/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/.github/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/.github/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/.github/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/.github/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/.github/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/.github/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/.github/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/.github/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/.github/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/.github/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/.github/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/.github/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/.github/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/.github/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/.github/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/.github/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/.github/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/.github/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/.github/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/.github/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/.github/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/.github/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/.github/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/.github/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/.github/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/.github/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/.github/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/.github/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/.github/deployments',
#   'created_at': '2019-02-18T18:59:22Z',
#   'updated_at': '2024-10-28T21:35:35Z',
#   'pushed_at': '2024-10-18T22:23:05Z',
#   'git_url': 'git://github.com/amzn/.github.git',
#   'ssh_url': 'git@github.com:amzn/.github.git',
#   'clone_url': 'https://github.com/amzn/.github.git',
#   'svn_url': 'https://github.com/amzn/.github',
#   'homepage': None,
#   'size': 24,
#   'stargazers_count': 14,
#   'watchers_count': 14,
#   'language': None,
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 357,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 3,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 357,
#   'open_issues': 3,
#   'watchers': 14,
#   'default_branch': 'master'},
#  {'id': 492978607,
#   'node_id': 'R_kgDOHWJBrw',
#   'name': 'ads-advanced-tools-docs',
#   'full_name': 'amzn/ads-advanced-tools-docs',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'description': 'Code samples and supplements for the Amazon Ads advanced tools center',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-advanced-tools-docs/deployments',
#   'created_at': '2022-05-16T19:49:03Z',
#   'updated_at': '2024-11-08T07:06:49Z',
#   'pushed_at': '2024-07-18T14:40:53Z',
#   'git_url': 'git://github.com/amzn/ads-advanced-tools-docs.git',
#   'ssh_url': 'git@github.com:amzn/ads-advanced-tools-docs.git',
#   'clone_url': 'https://github.com/amzn/ads-advanced-tools-docs.git',
#   'svn_url': 'https://github.com/amzn/ads-advanced-tools-docs',
#   'homepage': 'https://advertising.amazon.com/API/docs/en-us/index',
#   'size': 370,
#   'stargazers_count': 97,
#   'watchers_count': 97,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': False,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': True,
#   'forks_count': 32,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 28,
#   'license': {'key': 'mit-0',
#    'name': 'MIT No Attribution',
#    'spdx_id': 'MIT-0',
#    'url': 'https://api.github.com/licenses/mit-0',
#    'node_id': 'MDc6TGljZW5zZTQx'},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': ['amazon', 'amazon-ads-api', 'amazon-marketing-stream'],
#   'visibility': 'public',
#   'forks': 32,
#   'open_issues': 28,
#   'watchers': 97,
#   'default_branch': 'main'},
#  {'id': 674005216,
#   'node_id': 'R_kgDOKCyA4A',
#   'name': 'ads-pao-amznjs-gtm-template',
#   'full_name': 'amzn/ads-pao-amznjs-gtm-template',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template',
#   'forks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/ads-pao-amznjs-gtm-template/deployments',
#   'created_at': '2023-08-02T23:41:56Z',
#   'updated_at': '2024-09-05T08:32:25Z',
#   'pushed_at': '2024-06-03T16:53:23Z',
#   'git_url': 'git://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'ssh_url': 'git@github.com:amzn/ads-pao-amznjs-gtm-template.git',
#   'clone_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template.git',
#   'svn_url': 'https://github.com/amzn/ads-pao-amznjs-gtm-template',
#   'homepage': None,
#   'size': 165,
#   'stargazers_count': 3,
#   'watchers_count': 3,
#   'language': 'Smarty',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 3,
#   'default_branch': 'main'},
#  {'id': 41117941,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MTExNzk0MQ==',
#   'name': 'alexa-coho',
#   'full_name': 'amzn/alexa-coho',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-coho',
#   'description': 'Sample code for building skill adapters for Alexa Connected Home using the Lighting API',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-coho',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-coho/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-coho/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-coho/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-coho/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-coho/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-coho/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-coho/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-coho/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-coho/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-coho/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-coho/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-coho/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-coho/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-coho/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-coho/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-coho/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-coho/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-coho/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-coho/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-coho/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-coho/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-coho/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-coho/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-coho/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-coho/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-coho/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-coho/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-coho/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-coho/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-coho/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-coho/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-coho/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-coho/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-coho/deployments',
#   'created_at': '2015-08-20T20:42:31Z',
#   'updated_at': '2024-07-11T01:03:40Z',
#   'pushed_at': '2023-04-01T08:35:29Z',
#   'git_url': 'git://github.com/amzn/alexa-coho.git',
#   'ssh_url': 'git@github.com:amzn/alexa-coho.git',
#   'clone_url': 'https://github.com/amzn/alexa-coho.git',
#   'svn_url': 'https://github.com/amzn/alexa-coho',
#   'homepage': None,
#   'size': 209,
#   'stargazers_count': 63,
#   'watchers_count': 63,
#   'language': 'JavaScript',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 24,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 4,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 24,
#   'open_issues': 4,
#   'watchers': 63,
#   'default_branch': 'master'},
#  {'id': 39471546,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzOTQ3MTU0Ng==',
#   'name': 'alexa-skills-kit-js',
#   'full_name': 'amzn/alexa-skills-kit-js',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'description': ' SDK and example code for building voice-enabled skills for the Amazon Echo. ',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js',
#   'forks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/alexa-skills-kit-js/deployments',
#   'created_at': '2015-07-21T21:46:48Z',
#   'updated_at': '2024-08-04T00:31:19Z',
#   'pushed_at': '2020-10-01T06:10:20Z',
#   'git_url': 'git://github.com/amzn/alexa-skills-kit-js.git',
#   'ssh_url': 'git@github.com:amzn/alexa-skills-kit-js.git',
#   'clone_url': 'https://github.com/amzn/alexa-skills-kit-js.git',
#   'svn_url': 'https://github.com/amzn/alexa-skills-kit-js',
#   'homepage': 'http://developer.amazon.com/ask',
#   'size': 8827,
#   'stargazers_count': 1135,
#   'watchers_count': 1135,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 1040,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 11,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1040,
#   'open_issues': 11,
#   'watchers': 1135,
#   'default_branch': 'master'},
#  {'id': 495519526,
#   'node_id': 'R_kgDOHYkHJg',
#   'name': 'amazon-ads-advertiser-audience-normalization-sdk-py',
#   'full_name': 'amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-ads-advertiser-audience-normalization-sdk-py/deployments',
#   'created_at': '2022-05-23T17:59:56Z',
#   'updated_at': '2024-05-30T21:19:04Z',
#   'pushed_at': '2022-05-23T21:20:34Z',
#   'git_url': 'git://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'ssh_url': 'git@github.com:amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'clone_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py.git',
#   'svn_url': 'https://github.com/amzn/amazon-ads-advertiser-audience-normalization-sdk-py',
#   'homepage': None,
#   'size': 16,
#   'stargazers_count': 9,
#   'watchers_count': 9,
#   'language': 'Python',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 4,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 4,
#   'open_issues': 0,
#   'watchers': 9,
#   'default_branch': 'main'},
#  {'id': 61315875,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk2MTMxNTg3NQ==',
#   'name': 'amazon-advertising-api-php-sdk',
#   'full_name': 'amzn/amazon-advertising-api-php-sdk',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'description': '⛔️ DEPRECATED - Amazon Advertising API PHP Client Library',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-advertising-api-php-sdk/deployments',
#   'created_at': '2016-06-16T18:16:46Z',
#   'updated_at': '2024-09-14T07:43:36Z',
#   'pushed_at': '2020-09-20T17:25:48Z',
#   'git_url': 'git://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'ssh_url': 'git@github.com:amzn/amazon-advertising-api-php-sdk.git',
#   'clone_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk.git',
#   'svn_url': 'https://github.com/amzn/amazon-advertising-api-php-sdk',
#   'homepage': '',
#   'size': 49,
#   'stargazers_count': 93,
#   'watchers_count': 93,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 66,
#   'mirror_url': None,
#   'archived': True,
#   'disabled': False,
#   'open_issues_count': 14,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 66,
#   'open_issues': 14,
#   'watchers': 93,
#   'default_branch': 'master'},
#  {'id': 429297502,
#   'node_id': 'R_kgDOGZaPXg',
#   'name': 'amazon-codeguru-profiler-for-spark',
#   'full_name': 'amzn/amazon-codeguru-profiler-for-spark',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'description': 'A Spark plugin for CPU and memory profiling',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-codeguru-profiler-for-spark/deployments',
#   'created_at': '2021-11-18T04:37:55Z',
#   'updated_at': '2024-10-01T18:04:47Z',
#   'pushed_at': '2024-05-30T18:52:25Z',
#   'git_url': 'git://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'ssh_url': 'git@github.com:amzn/amazon-codeguru-profiler-for-spark.git',
#   'clone_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark.git',
#   'svn_url': 'https://github.com/amzn/amazon-codeguru-profiler-for-spark',
#   'homepage': '',
#   'size': 2352,
#   'stargazers_count': 18,
#   'watchers_count': 18,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 11,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
# ...
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-csharp/deployments',
#   'created_at': '2014-12-06T01:01:38Z',
#   'updated_at': '2024-07-13T00:52:34Z',
#   'pushed_at': '2024-05-30T18:46:45Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-csharp.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-csharp.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-csharp',
#   'homepage': 'https://payments.amazon.com/developer',
#   'size': 28264,
#   'stargazers_count': 48,
#   'watchers_count': 48,
#   'language': 'C#',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 42,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 12,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 42,
#   'open_issues': 12,
#   'watchers': 48,
#   'default_branch': 'master'},
#  {'id': 27605347,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzYwNTM0Nw==',
#   'name': 'amazon-pay-sdk-java',
#   'full_name': 'amzn/amazon-pay-sdk-java',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'description': ' Amazon Pay Java SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-java/deployments',
#   'created_at': '2014-12-05T18:51:43Z',
#   'updated_at': '2024-09-09T14:17:34Z',
#   'pushed_at': '2024-08-10T17:28:22Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-java.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-java.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-java.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-java',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 13957,
#   'stargazers_count': 58,
#   'watchers_count': 58,
#   'language': 'Java',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 51,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 15,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 51,
#   'open_issues': 15,
#   'watchers': 58,
#   'default_branch': 'master'},
#  {'id': 26331269,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjMzMTI2OQ==',
#   'name': 'amazon-pay-sdk-php',
#   'full_name': 'amzn/amazon-pay-sdk-php',
#   'private': False,
#   'owner': {'login': 'amzn',
#    'id': 8594673,
#    'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg1OTQ2NzM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8594673?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/amzn',
#    'html_url': 'https://github.com/amzn',
#    'followers_url': 'https://api.github.com/users/amzn/followers',
#    'following_url': 'https://api.github.com/users/amzn/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/amzn/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/amzn/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/amzn/subscriptions',
#    'organizations_url': 'https://api.github.com/users/amzn/orgs',
#    'repos_url': 'https://api.github.com/users/amzn/repos',
#    'events_url': 'https://api.github.com/users/amzn/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/amzn/received_events',
#    'type': 'Organization',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'description': 'Amazon Pay PHP SDK',
#   'fork': False,
#   'url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php',
#   'forks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/forks',
#   'keys_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/teams',
#   'hooks_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/hooks',
#   'issue_events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/events',
#   'assignees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/tags',
#   'blobs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/languages',
#   'stargazers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/stargazers',
#   'contributors_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contributors',
#   'subscribers_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscribers',
#   'subscription_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/subscription',
#   'commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/merges',
#   'archive_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/downloads',
#   'issues_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/amzn/amazon-pay-sdk-php/deployments',
#   'created_at': '2014-11-07T18:00:47Z',
#   'updated_at': '2024-09-17T15:30:38Z',
#   'pushed_at': '2024-05-14T13:04:33Z',
#   'git_url': 'git://github.com/amzn/amazon-pay-sdk-php.git',
#   'ssh_url': 'git@github.com:amzn/amazon-pay-sdk-php.git',
#   'clone_url': 'https://github.com/amzn/amazon-pay-sdk-php.git',
#   'svn_url': 'https://github.com/amzn/amazon-pay-sdk-php',
#   'homepage': 'https://pay.amazon.com/documentation',
#   'size': 877,
#   'stargazers_count': 208,
#   'watchers_count': 208,
#   'language': 'PHP',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 92,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 37,
#   'license': {'key': 'apache-2.0',
#    'name': 'Apache License 2.0',
#    'spdx_id': 'Apache-2.0',
#    'url': 'https://api.github.com/licenses/apache-2.0',
#    'node_id': 'MDc6TGljZW5zZTI='},
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 92,
#   'open_issues': 37,
#   'watchers': 208,
#   'default_branch': 'master'}]

# %% [markdown]
# ### Autenticação

# %% [markdown]
# Solicitações autenticadas têm um limite de taxa mais alto. Quando um usuário faz uma solicitação autenticada, ele fornece credenciais que comprovam sua identidade, o que permite que a API confie nele e lhe conceda acesso a recursos e funcionalidades adicionais.
#
# Além disso, a maioria das APIs estabelece limites para o número de solicitações que um usuário pode fazer em um determinado período de tempo, conhecido como 'limite de taxa'. Quando um usuário faz solicitações autenticadas, a API geralmente permite que ele faça mais solicitações em um determinado período de tempo, devido à maior confiança e credibilidade que a autenticação fornece.

# %% [markdown]
# ### Paginando os repositórios

# %% [markdown]
# ## Transformando os dados

# %% [markdown]
# ### Nomes dos repositórios

# %% [markdown]
# ### Linguagens dos repositórios

# %% [markdown]
# ### Criando um DataFrame

# %% [markdown]
# Salvando o DataFrame

# %% [markdown]
# ## Armazenando os dados

# %% [markdown]
# ### Criando repositório com POST

# %% [markdown]
# ### Formato do arquivo

# %% [markdown]
# ### Upload de arquivo com PUT
